# %%
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm
from time import time, sleep

# %%
url_template = "https://www.drugs.com/comments/bupropion/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:27<00:00,  1.85s/it]

# %%
df = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df['Drug'] = 'Bupropion'
df['Condition'] = 'Depression'
df['Major Interaction'] = 212
df['Moderate Interaction'] = 203
df['Minor Interaction'] = 5
df['Dosage'] = 'oral'
df.drop_duplicates(inplace=True)
df
# Out:
#      Rating              Date                         Taken Helpful  \
# 0         9  October 28, 2020  Taken for 6 months to 1 year       1
# 1        10  October 19, 2020  Taken for 6 months to 1 year      39
# 2        10  October 14, 2020                           NaN      10
# 3         8  October 10, 2020                           NaN       1
# 4         1   October 4, 2020       Taken for 5 to 10 years       4
# ...     ...               ...                           ...     ...
# 1147     10     June 14, 2008                           NaN     139
# 1148      8      June 8, 2008                           NaN     149
# 1149     10      May 19, 2008                           NaN     159
# 1150      8     April 4, 2008                           NaN     214
# 1151     10    March 27, 2008                           NaN     274
#
#                                                  Review       Drug  \
# 0     Budeprion XL (bupropion):\t\t\t“I'd been on Bu...  Bupropion
# 1     Wellbutrin XL (bupropion):\t\t\t“Real and hone...  Bupropion
# 2     “I am just so thankful for this medication bup...  Bupropion
# 3     Aplenzin (bupropion):\t\t\t“I've been taking W...  Bupropion
# 4     “I’m giving this a rating of 1 because of my p...  Bupropion
# ...                                                 ...        ...
# 1147  Wellbutrin SR (bupropion):\t\t\t“I have tried ...  Bupropion
# 1148  Wellbutrin SR (bupropion):\t\t\t“I started tak...  Bupropion
# 1149  Wellbutrin (bupropion):\t\t\t“I've been taking...  Bupropion
# 1150  Wellbutrin (bupropion):\t\t\t“I have tried man...  Bupropion
# 1151  Wellbutrin (bupropion):\t\t\t“I've been on thi...  Bupropion
#
#        Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0     Depression                212                   203                  5
# 1     Depression                212                   203                  5
# 2     Depression                212                   203                  5
# 3     Depression                212                   203                  5
# 4     Depression                212                   203                  5
# ...          ...                ...                   ...                ...
# 1147  Depression                212                   203                  5
# 1148  Depression                212                   203                  5
# 1149  Depression                212                   203                  5
# 1150  Depression                212                   203                  5
# 1151  Depression                212                   203                  5
#
#      Dosage
# 0      oral
# 1      oral
# 2      oral
# 3      oral
# 4      oral
# ...     ...
# 1147   oral
# 1148   oral
# 1149   oral
# 1150   oral
# 1151   oral
#
# [1127 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/sertraline/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:26<00:00,  1.84s/it]

# %%
df1 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df1['Drug'] = 'Sertraline'
df1['Condition'] = 'Depression'
df1['Major Interaction'] = 140
df1['Moderate Interaction'] = 466
df1['Minor Interaction'] = 7
df1['Dosage'] = 'oral'
df1.drop_duplicates(inplace=True)
df1
# Out:
#      Rating               Date                        Taken Helpful  \
# 0         1   November 2, 2020                          NaN      10
# 1        10   October 18, 2020                          NaN      14
# 2         3    October 4, 2020  Taken for less than 1 month      12
# 3        10    October 3, 2020      Taken for 1 to 6 months      37
# 4        10    October 2, 2020                          NaN      44
# ...     ...                ...                          ...     ...
# 1099      8  February 26, 2008                          NaN       3
# 1100    NaN    January 3, 2008                          NaN      60
# 1101    NaN  November 10, 2007                          NaN     129
# 1102    NaN   November 3, 2007                          NaN     127
# 1103    NaN   October 12, 2007                          NaN      87
#
#                                                  Review        Drug  \
# 0     Zoloft (sertraline):\t\t\t“I’m 28, 106 lbs & n...  Sertraline
# 1     “I literally just took the pill for the first ...  Sertraline
# 2     “Suffered with mild depression for as long as ...  Sertraline
# 3     “I have taken sertraline 3 times in my life. F...  Sertraline
# 4     Zoloft (sertraline):\t\t\t“I literally felt so...  Sertraline
# ...                                                 ...         ...
# 1099  “I have been taking Zoloft for about 7 years. ...  Sertraline
# 1100  Zoloft (sertraline):\t\t\t“I have been taking ...  Sertraline
# 1101  Zoloft (sertraline):\t\t\t“I have been on Zolo...  Sertraline
# 1102  Zoloft (sertraline):\t\t\t“I have been taking ...  Sertraline
# 1103  Zoloft (sertraline):\t\t\t“I started taking Zo...  Sertraline
#
#        Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0     Depression                140                   466                  7
# 1     Depression                140                   466                  7
# 2     Depression                140                   466                  7
# 3     Depression                140                   466                  7
# 4     Depression                140                   466                  7
# ...          ...                ...                   ...                ...
# 1099  Depression                140                   466                  7
# 1100  Depression                140                   466                  7
# 1101  Depression                140                   466                  7
# 1102  Depression                140                   466                  7
# 1103  Depression                140                   466                  7
#
#      Dosage
# 0      oral
# 1      oral
# 2      oral
# 3      oral
# 4      oral
# ...     ...
# 1099   oral
# 1100   oral
# 1101   oral
# 1102   oral
# 1103   oral
#
# [1079 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/venlafaxine/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:24<00:00,  1.79s/it]

# %%
df2 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df2['Drug'] = 'Venlafaxine'
df2['Condition'] = 'Depression'
df2['Major Interaction'] = 139
df2['Moderate Interaction'] = 486
df2['Minor Interaction'] = 5
df2['Dosage'] = 'oral'
df2.drop_duplicates(inplace=True)
df2
# Out:
#     Rating                Date                       Taken Helpful  \
# 0       10    October 13, 2020                         NaN      27
# 1        1     October 3, 2020     Taken for 1 to 6 months       3
# 2        9     October 2, 2020                         NaN      16
# 3        4  September 28, 2020  Taken for 10 years or more       6
# 4        2   September 5, 2020     Taken for 1 to 6 months      11
# ..     ...                 ...                         ...     ...
# 911    NaN     January 6, 2008                         NaN     175
# 912    NaN    November 4, 2007                         NaN       9
# 913    NaN    October 22, 2007                         NaN      51
# 914    NaN   September 8, 2007                         NaN     144
# 915    NaN     August 14, 2007                         NaN     188
#
#                                                 Review         Drug  \
# 0    Effexor XR (venlafaxine):\t\t\t“Please remembe...  Venlafaxine
# 1    “Terrible drug. Crashed my mood and made me ap...  Venlafaxine
# 2    Effexor (venlafaxine):\t\t\t“From my experienc...  Venlafaxine
# 3    Effexor (venlafaxine):\t\t\t“Took 75 mg Effexo...  Venlafaxine
# 4    Effexor XR (venlafaxine):\t\t\t“I don’t have a...  Venlafaxine
# ..                                                 ...          ...
# 911  Effexor (venlafaxine):\t\t\t“I ended up in the...  Venlafaxine
# 912  Effexor (venlafaxine):\t\t\t“First, I have per...  Venlafaxine
# 913  Effexor (venlafaxine):\t\t\t“I noticed when I ...  Venlafaxine
# 914  Effexor (venlafaxine):\t\t\t“My girlfriend has...  Venlafaxine
# 915  Effexor (venlafaxine):\t\t\t“I was on effexor ...  Venlafaxine
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                139                   486                  5
# 1    Depression                139                   486                  5
# 2    Depression                139                   486                  5
# 3    Depression                139                   486                  5
# 4    Depression                139                   486                  5
# ..          ...                ...                   ...                ...
# 911  Depression                139                   486                  5
# 912  Depression                139                   486                  5
# 913  Depression                139                   486                  5
# 914  Depression                139                   486                  5
# 915  Depression                139                   486                  5
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 911   oral
# 912   oral
# 913   oral
# 914   oral
# 915   oral
#
# [891 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/escitalopram/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:21<00:00,  1.74s/it]

# %%
df3 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df3['Drug'] = 'Escitalopram'
df3['Condition'] = 'Depression'
df3['Major Interaction'] = 243
df3['Moderate Interaction'] = 353
df3['Minor Interaction'] = 41
df3['Dosage'] = 'oral'
df3.drop_duplicates(inplace=True)
df3
# Out:
#     Rating                Date                         Taken Helpful  \
# 0       10    October 24, 2020       Taken for 1 to 6 months       4
# 1        3    October 18, 2020   Taken for less than 1 month       5
# 2        9  September 29, 2020   Taken for less than 1 month      78
# 3        9  September 26, 2020        Taken for 2 to 5 years      21
# 4       10  September 22, 2020  Taken for 6 months to 1 year      75
# ..     ...                 ...                           ...     ...
# 810      8       March 2, 2008                           NaN     148
# 811      7   February 25, 2008                           NaN      31
# 812      6   February 25, 2008                           NaN      23
# 813    NaN   November 19, 2007                           NaN     160
# 814    NaN  September 28, 2007                           NaN      39
#
#                                                 Review          Drug  \
# 0    “I was prescribed this drug about 3 years ago ...  Escitalopram
# 1    Lexapro (escitalopram):\t\t\t“I had taken Lexa...  Escitalopram
# 2    Lexapro (escitalopram):\t\t\t“This medicine Le...  Escitalopram
# 3    Lexapro (escitalopram):\t\t\t“Overall, Lexapro...  Escitalopram
# 4    Lexapro (escitalopram):\t\t\t“I started taking...  Escitalopram
# ..                                                 ...           ...
# 810  Lexapro (escitalopram):\t\t\t“Been on Lexapro ...  Escitalopram
# 811  Lexapro (escitalopram):\t\t\t“I have had Bipol...  Escitalopram
# 812  Lexapro (escitalopram):\t\t\t“I've been on lex...  Escitalopram
# 813  Lexapro (escitalopram):\t\t\t“I am a 29 year o...  Escitalopram
# 814  Lexapro (escitalopram):\t\t\t“I am a 50 year o...  Escitalopram
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                243                   353                 41
# 1    Depression                243                   353                 41
# 2    Depression                243                   353                 41
# 3    Depression                243                   353                 41
# 4    Depression                243                   353                 41
# ..          ...                ...                   ...                ...
# 810  Depression                243                   353                 41
# 811  Depression                243                   353                 41
# 812  Depression                243                   353                 41
# 813  Depression                243                   353                 41
# 814  Depression                243                   353                 41
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 810   oral
# 811   oral
# 812   oral
# 813   oral
# 814   oral
#
# [790 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/vortioxetine/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:16<00:00,  1.63s/it]

# %%
df4 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df4['Drug'] = 'Vortioxetine'
df4['Condition'] = 'Depression'
df4['Major Interaction'] = 92
df4['Moderate Interaction'] = 234
df4['Minor Interaction'] = 1
df4['Dosage'] = 'oral'
df4.drop_duplicates(inplace=True)
df4
# Out:
#     Rating                Date                         Taken Helpful  \
# 0        9    October 23, 2020        Taken for 1 to 2 years       2
# 1        3     October 8, 2020  Taken for 6 months to 1 year      11
# 2        3     October 3, 2020       Taken for 1 to 6 months      13
# 3        1  September 28, 2020   Taken for less than 1 month      18
# 4       10  September 28, 2020  Taken for 6 months to 1 year      16
# ..     ...                 ...                           ...     ...
# 795      9    February 9, 2014                           NaN      67
# 796      8    February 3, 2014       Taken for 1 to 6 months      88
# 797      8    January 23, 2014   Taken for less than 1 month      10
# 798      2     January 8, 2014                           NaN      88
# 799      7   November 25, 2013                           NaN     104
#
#                                                 Review          Drug  \
# 0    “Love this. Been on many meds for many years a...  Vortioxetine
# 1    Trintellix (vortioxetine):\t\t\t“I have been o...  Vortioxetine
# 2    Trintellix (vortioxetine):\t\t\t“I took Trinte...  Vortioxetine
# 3    Trintellix (vortioxetine):\t\t\t“Have been tak...  Vortioxetine
# 4    Trintellix (vortioxetine):\t\t\t“I have Anxiet...  Vortioxetine
# ..                                                 ...           ...
# 795  Trintellix (vortioxetine):\t\t\t“I'm on week t...  Vortioxetine
# 796  Trintellix (vortioxetine):\t\t\t“I have been o...  Vortioxetine
# 797  “I have been taking 5mg of Brintellix for a we...  Vortioxetine
# 798  Trintellix (vortioxetine):\t\t\t“I was so hope...  Vortioxetine
# 799  Trintellix (vortioxetine):\t\t\t“So far so goo...  Vortioxetine
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                 92                   234                  1
# 1    Depression                 92                   234                  1
# 2    Depression                 92                   234                  1
# 3    Depression                 92                   234                  1
# 4    Depression                 92                   234                  1
# ..          ...                ...                   ...                ...
# 795  Depression                 92                   234                  1
# 796  Depression                 92                   234                  1
# 797  Depression                 92                   234                  1
# 798  Depression                 92                   234                  1
# 799  Depression                 92                   234                  1
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 795   oral
# 796   oral
# 797   oral
# 798   oral
# 799   oral
#
# [775 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/desvenlafaxine/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:20<00:00,  1.71s/it]

# %%
df5 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df5['Drug'] = 'Desvenlafaxine'
df5['Condition'] = 'Depression'
df5['Major Interaction'] = 89
df5['Moderate Interaction'] = 358
df5['Minor Interaction'] = 2
df5['Dosage'] = 'oral'
df5.drop_duplicates(inplace=True)
df5
# Out:
#     Rating                Date                    Taken Helpful  \
# 0       10     October 9, 2020   Taken for 2 to 5 years       3
# 1        9  September 22, 2020  Taken for 1 to 6 months       1
# 2      NaN  September 19, 2020                      NaN       6
# 3       10     August 21, 2020  Taken for 1 to 6 months       7
# 4       10     August 18, 2020                      NaN     103
# ..     ...                 ...                      ...     ...
# 791      9     August 16, 2008                      NaN      49
# 792      8       July 24, 2008                      NaN     361
# 793     10       June 24, 2008                      NaN     513
# 794      9       June 24, 2008                      NaN     344
# 795      8       June 24, 2008                      NaN       2
#
#                                                 Review            Drug  \
# 0    “In 2016, I was a mess, spurred on by emotiona...  Desvenlafaxine
# 1    “Before trying this medication desvenlafaxine,...  Desvenlafaxine
# 2    Pristiq (desvenlafaxine):\t\t\t“Just started P...  Desvenlafaxine
# 3    “Pristiq has been a lifesaver for me multiple ...  Desvenlafaxine
# 4    Pristiq (desvenlafaxine):\t\t\t“Picture this: ...  Desvenlafaxine
# ..                                                 ...             ...
# 791  Pristiq (desvenlafaxine):\t\t\t“I have been on...  Desvenlafaxine
# 792  Pristiq (desvenlafaxine):\t\t\t“After a little...  Desvenlafaxine
# 793  Pristiq (desvenlafaxine):\t\t\t“After trying s...  Desvenlafaxine
# 794  Pristiq (desvenlafaxine):\t\t\t“Has helped me ...  Desvenlafaxine
# 795  “Excellent Medicine. No side effects. I feel l...  Desvenlafaxine
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                 89                   358                  2
# 1    Depression                 89                   358                  2
# 2    Depression                 89                   358                  2
# 3    Depression                 89                   358                  2
# 4    Depression                 89                   358                  2
# ..          ...                ...                   ...                ...
# 791  Depression                 89                   358                  2
# 792  Depression                 89                   358                  2
# 793  Depression                 89                   358                  2
# 794  Depression                 89                   358                  2
# 795  Depression                 89                   358                  2
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 791   oral
# 792   oral
# 793   oral
# 794   oral
# 795   oral
#
# [771 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/desvenlafaxine/pristiq-for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:13<00:00,  1.57s/it]

# %%
df6 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df6['Drug'] = 'Pristiq'
df6['Condition'] = 'Depression'
df6['Major Interaction'] = 89
df6['Moderate Interaction'] = 358
df6['Minor Interaction'] = 2
df6['Dosage'] = 'oral'
df6.drop_duplicates(inplace=True)
df6
# Out:
#     Rating                Date                        Taken Helpful  \
# 0      NaN  September 19, 2020                          NaN       6
# 1       10     August 18, 2020                          NaN     103
# 2        4         May 4, 2020      Taken for 5 to 10 years      53
# 3       10      April 29, 2020  Taken for less than 1 month      39
# 4        9      March 10, 2020      Taken for 5 to 10 years      89
# ..     ...                 ...                          ...     ...
# 742      8     August 19, 2008                          NaN     158
# 743      9     August 16, 2008                          NaN      49
# 744      8       July 24, 2008                          NaN     361
# 745     10       June 24, 2008                          NaN     513
# 746      9       June 24, 2008                          NaN     344
#
#                                                 Review     Drug   Condition  \
# 0    “Just started Pristiq generic 50 Mg Hopefully ...  Pristiq  Depression
# 1    “Picture this: I am dressed and ready to sell ...  Pristiq  Depression
# 2    “Pristiq has benefits, BUT, be aware of seriou...  Pristiq  Depression
# 3    “Pristiq save my life. It is the only option I...  Pristiq  Depression
# 4    “Pristiq 50 mg is the ONLY medication which ha...  Pristiq  Depression
# ..                                                 ...      ...         ...
# 742  “I have been taking Pristiq for 5 days.  This ...  Pristiq  Depression
# 743  “I have been on Pristiq for four weeks and as ...  Pristiq  Depression
# 744  “After a little over two months on Pristiq, I ...  Pristiq  Depression
# 745  “After trying several of the top ten antidepre...  Pristiq  Depression
# 746  “Has helped me more than any treatment in the ...  Pristiq  Depression
#
#      Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                   89                   358                  2   oral
# 1                   89                   358                  2   oral
# 2                   89                   358                  2   oral
# 3                   89                   358                  2   oral
# 4                   89                   358                  2   oral
# ..                 ...                   ...                ...    ...
# 742                 89                   358                  2   oral
# 743                 89                   358                  2   oral
# 744                 89                   358                  2   oral
# 745                 89                   358                  2   oral
# 746                 89                   358                  2   oral
#
# [722 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/citalopram/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:19<00:00,  1.70s/it]

# %%
df7 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df7['Drug'] = 'Citalopram'
df7['Condition'] = 'Depression'
df7['Major Interaction'] = 261
df7['Moderate Interaction'] = 350
df7['Minor Interaction'] = 44
df7['Dosage'] = 'oral'
df7.drop_duplicates(inplace=True)
df7
# Out:
#     Rating                Date                         Taken Helpful  \
# 0       10    October 11, 2020       Taken for 1 to 6 months       3
# 1        9     October 6, 2020                           NaN       7
# 2       10  September 10, 2020        Taken for 1 to 2 years      19
# 3        8     August 20, 2020  Taken for 6 months to 1 year       9
# 4        1       June 24, 2020  Taken for 6 months to 1 year       7
# ..     ...                 ...                           ...     ...
# 677     10       April 1, 2008                           NaN     272
# 678      8      March 25, 2008                           NaN     783
# 679      8      March 20, 2008                           NaN      17
# 680      8      March 20, 2008                           NaN      19
# 681     10       March 7, 2008                           NaN     417
#
#                                                 Review        Drug  \
# 0    “After 5 weeks on 40 mg I feel so much better....  Citalopram
# 1    “I really think that term "old self" which I s...  Citalopram
# 2    Celexa (citalopram):\t\t\t“This medication Cel...  Citalopram
# 3    “I was on this citalopram for 8 months, it rea...  Citalopram
# 4    “I used citalopram due to perceived depression...  Citalopram
# ..                                                 ...         ...
# 677  Celexa (citalopram):\t\t\t“It is so nice to ha...  Citalopram
# 678  Celexa (citalopram):\t\t\t“I responded after o...  Citalopram
# 679  “I have been taking the med for about 3 months...  Citalopram
# 680  “I suffer from quite bad depression, anxiety, ...  Citalopram
# 681  Celexa (citalopram):\t\t\t“I was fortunate to ...  Citalopram
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                261                   350                 44
# 1    Depression                261                   350                 44
# 2    Depression                261                   350                 44
# 3    Depression                261                   350                 44
# 4    Depression                261                   350                 44
# ..          ...                ...                   ...                ...
# 677  Depression                261                   350                 44
# 678  Depression                261                   350                 44
# 679  Depression                261                   350                 44
# 680  Depression                261                   350                 44
# 681  Depression                261                   350                 44
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 677   oral
# 678   oral
# 679   oral
# 680   oral
# 681   oral
#
# [657 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/duloxetine/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:22<00:00,  1.75s/it]

# %%
df8 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df8['Drug'] = 'Duloxetine'
df8['Condition'] = 'Depression'
df8['Major Interaction'] = 100
df8['Moderate Interaction'] = 435
df8['Minor Interaction'] = 23
df8['Dosage'] = 'oral'
df8.drop_duplicates(inplace=True)
df8
# Out:
#     Rating              Date                         Taken Helpful  \
# 0        9  October 24, 2020       Taken for 5 to 10 years       8
# 1       10  October 22, 2020   Taken for less than 1 month       2
# 2        1  October 18, 2020   Taken for less than 1 month       9
# 3        9  October 11, 2020  Taken for 6 months to 1 year      12
# 4       10  October 10, 2020        Taken for 1 to 2 years       1
# ..     ...               ...                           ...     ...
# 662    NaN    March 12, 2008                           NaN     128
# 663    NaN  October 22, 2007                           NaN     169
# 664    NaN  October 19, 2007                           NaN      89
# 665    NaN   October 4, 2007                           NaN     142
# 666    NaN   October 2, 2007                           NaN     183
#
#                                                 Review        Drug  \
# 0    Cymbalta (duloxetine):\t\t\t“I have been on Cy...  Duloxetine
# 1    “On my first day of Duloxotine I felt so good....  Duloxetine
# 2    Cymbalta (duloxetine):\t\t\t“Have been on Cymb...  Duloxetine
# 3    Cymbalta (duloxetine):\t\t\t“I had been diagno...  Duloxetine
# 4    “I have been on Duloxetine for just over a yea...  Duloxetine
# ..                                                 ...         ...
# 662  Cymbalta (duloxetine):\t\t\t“To begin with I e...  Duloxetine
# 663  Cymbalta (duloxetine):\t\t\t“I have been using...  Duloxetine
# 664  Cymbalta (duloxetine):\t\t\t“Taking Cymbalta 2...  Duloxetine
# 665  Cymbalta (duloxetine):\t\t\t“ Recently stopped...  Duloxetine
# 666  Cymbalta (duloxetine):\t\t\t“I have been on Cy...  Duloxetine
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                100                   435                 23
# 1    Depression                100                   435                 23
# 2    Depression                100                   435                 23
# 3    Depression                100                   435                 23
# 4    Depression                100                   435                 23
# ..          ...                ...                   ...                ...
# 662  Depression                100                   435                 23
# 663  Depression                100                   435                 23
# 664  Depression                100                   435                 23
# 665  Depression                100                   435                 23
# 666  Depression                100                   435                 23
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 662   oral
# 663   oral
# 664   oral
# 665   oral
# 666   oral
#
# [642 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/fluoxetine/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:19<00:00,  1.70s/it]

# %%
df9 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df9['Drug'] = 'Fluoxetine'
df9['Condition'] = 'Depression'
df9['Major Interaction'] = 144
df9['Moderate Interaction'] = 461
df9['Minor Interaction'] = 22
df9['Dosage'] = 'oral'
df9.drop_duplicates(inplace=True)
df9
# Out:
#     Rating                Date                         Taken Helpful  \
# 0        9     October 4, 2020       Taken for 1 to 6 months      25
# 1        8     October 4, 2020   Taken for less than 1 month      26
# 2        9     October 4, 2020  Taken for 6 months to 1 year      10
# 3        1  September 24, 2020                           NaN      16
# 4       10  September 24, 2020                           NaN      12
# ..     ...                 ...                           ...     ...
# 618      9   September 4, 2008                           NaN       9
# 619      7     August 24, 2008                           NaN       4
# 620     10       June 21, 2008                           NaN     325
# 621      9      April 30, 2008                           NaN      34
# 622      9      March 21, 2008                           NaN     180
#
#                                                 Review        Drug  \
# 0    “I started a low dose of fluoxetine about 6 we...  Fluoxetine
# 1    Prozac (fluoxetine):\t\t\t“Just started Prozac...  Fluoxetine
# 2    “Fluoxetine the best antidepressant I've been ...  Fluoxetine
# 3    Prozac (fluoxetine):\t\t\t“Absolute rubbish. C...  Fluoxetine
# 4    “At the first I wasn't too sure about the whol...  Fluoxetine
# ..                                                 ...         ...
# 618  “I was diagnosed with depression after a serio...  Fluoxetine
# 619  “I'm 17 years old and I've been diagnosed with...  Fluoxetine
# 620  Prozac (fluoxetine):\t\t\t“Well I just started...  Fluoxetine
# 621  “I have now been taking this medication for ju...  Fluoxetine
# 622  Prozac (fluoxetine):\t\t\t“I took Prozac succe...  Fluoxetine
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                144                   461                 22
# 1    Depression                144                   461                 22
# 2    Depression                144                   461                 22
# 3    Depression                144                   461                 22
# 4    Depression                144                   461                 22
# ..          ...                ...                   ...                ...
# 618  Depression                144                   461                 22
# 619  Depression                144                   461                 22
# 620  Depression                144                   461                 22
# 621  Depression                144                   461                 22
# 622  Depression                144                   461                 22
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 618   oral
# 619   oral
# 620   oral
# 621   oral
# 622   oral
#
# [598 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/vilazodone/for-depression.html?page={}"
max_results_per_page = 47
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 47/47 [01:13<00:00,  1.56s/it]

# %%
df10 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df10['Drug'] = 'Vilazodone'
df10['Condition'] = 'Depression'
df10['Major Interaction'] = 109
df10['Moderate Interaction'] = 274
df10['Minor Interaction'] = 3
df10['Dosage'] = 'oral'
df10.drop_duplicates(inplace=True)
df10
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        7     October 4, 2020                          NaN       9
# 1        5  September 10, 2020      Taken for 1 to 6 months       1
# 2        8   September 2, 2020                          NaN      30
# 3        1        May 25, 2020  Taken for less than 1 month      29
# 4        7         May 8, 2020                          NaN      30
# ..     ...                 ...                          ...     ...
# 594      1   September 1, 2011                          NaN      89
# 595     10     August 30, 2011                          NaN     217
# 596     10     August 18, 2011                          NaN     279
# 597     10     August 13, 2011                          NaN     412
# 598      8     August 11, 2011                          NaN     115
#
#                                                 Review        Drug  \
# 0    Viibryd (vilazodone):\t\t\t“I’ve been on sever...  Vilazodone
# 1    “vilazodone is fine for the depression but it ...  Vilazodone
# 2    Viibryd (vilazodone):\t\t\t“I have had issues ...  Vilazodone
# 3    Viibryd (vilazodone):\t\t\t“Been on this Viibr...  Vilazodone
# 4    Viibryd (vilazodone):\t\t\t“My issues are  Gen...  Vilazodone
# ..                                                 ...         ...
# 594  Viibryd (vilazodone):\t\t\t“I am feeling subst...  Vilazodone
# 595  Viibryd (vilazodone):\t\t\t“Whatever it takes ...  Vilazodone
# 596  Viibryd (vilazodone):\t\t\t“No side effects. R...  Vilazodone
# 597  Viibryd (vilazodone):\t\t\t“Awesome. Best medi...  Vilazodone
# 598  Viibryd (vilazodone):\t\t\t“Diarrhea is a majo...  Vilazodone
#
#       Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Depression                109                   274                  3
# 1    Depression                109                   274                  3
# 2    Depression                109                   274                  3
# 3    Depression                109                   274                  3
# 4    Depression                109                   274                  3
# ..          ...                ...                   ...                ...
# 594  Depression                109                   274                  3
# 595  Depression                109                   274                  3
# 596  Depression                109                   274                  3
# 597  Depression                109                   274                  3
# 598  Depression                109                   274                  3
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 594   oral
# 595   oral
# 596   oral
# 597   oral
# 598   oral
#
# [574 rows x 11 columns]

# %%
frames = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
df_depression = pd.concat(frames)

# %%
df_depression.reset_index(inplace=True, drop=True)

# %%
#save to CSV as master 
df_depression.to_csv("df_depression.csv")

# %%
df_depression
# Out:
#      Rating               Date                         Taken Helpful  \
# 0         9   October 28, 2020  Taken for 6 months to 1 year       1
# 1        10   October 19, 2020  Taken for 6 months to 1 year      39
# 2        10   October 14, 2020                           NaN      10
# 3         8   October 10, 2020                           NaN       1
# 4         1    October 4, 2020       Taken for 5 to 10 years       4
# ...     ...                ...                           ...     ...
# 8621      1  September 1, 2011                           NaN      89
# 8622     10    August 30, 2011                           NaN     217
# 8623     10    August 18, 2011                           NaN     279
# 8624     10    August 13, 2011                           NaN     412
# 8625      8    August 11, 2011                           NaN     115
#
#                                                  Review        Drug  \
# 0     Budeprion XL (bupropion):\t\t\t“I'd been on Bu...   Bupropion
# 1     Wellbutrin XL (bupropion):\t\t\t“Real and hone...   Bupropion
# 2     “I am just so thankful for this medication bup...   Bupropion
# 3     Aplenzin (bupropion):\t\t\t“I've been taking W...   Bupropion
# 4     “I’m giving this a rating of 1 because of my p...   Bupropion
# ...                                                 ...         ...
# 8621  Viibryd (vilazodone):\t\t\t“I am feeling subst...  Vilazodone
# 8622  Viibryd (vilazodone):\t\t\t“Whatever it takes ...  Vilazodone
# 8623  Viibryd (vilazodone):\t\t\t“No side effects. R...  Vilazodone
# 8624  Viibryd (vilazodone):\t\t\t“Awesome. Best medi...  Vilazodone
# 8625  Viibryd (vilazodone):\t\t\t“Diarrhea is a majo...  Vilazodone
#
#        Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0     Depression                212                   203                  5
# 1     Depression                212                   203                  5
# 2     Depression                212                   203                  5
# 3     Depression                212                   203                  5
# 4     Depression                212                   203                  5
# ...          ...                ...                   ...                ...
# 8621  Depression                109                   274                  3
# 8622  Depression                109                   274                  3
# 8623  Depression                109                   274                  3
# 8624  Depression                109                   274                  3
# 8625  Depression                109                   274                  3
#
#      Dosage
# 0      oral
# 1      oral
# 2      oral
# 3      oral
# 4      oral
# ...     ...
# 8621   oral
# 8622   oral
# 8623   oral
# 8624   oral
# 8625   oral
#
# [8626 rows x 11 columns]
