# %%
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm
from time import time, sleep

# %%
url_template = "https://www.drugs.com/comments/ranolazine/for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:28<00:00,  1.44s/it]

# %%
df = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df['Drug'] = 'Ranolazine'
df['Condition'] = 'Angina'
df['Major Interaction'] = 143
df['Moderate Interaction'] = 292
df['Minor Interaction'] = 30
df['Dosage'] = 'oral'
df.drop_duplicates(inplace=True)
df
# Out:
#    Rating               Date                        Taken Helpful  \
# 0       1     August 3, 2020  Taken for less than 1 month       5
# 1     NaN      March 2, 2020                          NaN      14
# 2       8   February 9, 2020  Taken for less than 1 month       6
# 3      10   October 17, 2019      Taken for 1 to 6 months      20
# 4       2    October 8, 2019  Taken for less than 1 month       9
# ..    ...                ...                          ...     ...
# 91      9   January 30, 2009                          NaN      80
# 92     10   January 17, 2009                          NaN      67
# 93      9   December 6, 2008                          NaN      65
# 94      9     March 20, 2008                          NaN      93
# 95    NaN  November 11, 2007                          NaN     108
#
#                                                Review        Drug Condition  \
# 0   Ranexa (ranolazine):\t\t\t“I have Microvascula...  Ranolazine    Angina
# 1   Ranexa (ranolazine):\t\t\t“Have been on Ranexa...  Ranolazine    Angina
# 2   “I'm a 62 yr old male. I had a heart attack 11...  Ranolazine    Angina
# 3   Ranexa (ranolazine):\t\t\t“Started Ranexa two ...  Ranolazine    Angina
# 4   Ranexa (ranolazine):\t\t\t“Tried several drugs...  Ranolazine    Angina
# ..                                                ...         ...       ...
# 91  Ranexa (ranolazine):\t\t\t“I didn't realize ho...  Ranolazine    Angina
# 92  Ranexa (ranolazine):\t\t\t“Suffering for 4 yea...  Ranolazine    Angina
# 93  Ranexa (ranolazine):\t\t\t“It's a difference o...  Ranolazine    Angina
# 94  Ranexa (ranolazine):\t\t\t“I've only been taki...  Ranolazine    Angina
# 95  Ranexa (ranolazine):\t\t\t“I have used Ranexa ...  Ranolazine    Angina
#
#     Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 143                   292                 30   oral
# 1                 143                   292                 30   oral
# 2                 143                   292                 30   oral
# 3                 143                   292                 30   oral
# 4                 143                   292                 30   oral
# ..                ...                   ...                ...    ...
# 91                143                   292                 30   oral
# 92                143                   292                 30   oral
# 93                143                   292                 30   oral
# 94                143                   292                 30   oral
# 95                143                   292                 30   oral
#
# [71 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/ranolazine/ranexa-for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:28<00:00,  1.42s/it]

# %%
df1 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df1['Drug'] = 'Ranexa'
df1['Condition'] = 'Angina'
df1['Major Interaction'] = 143
df1['Moderate Interaction'] = 292
df1['Minor Interaction'] = 30
df1['Dosage'] = 'oral'
df1.drop_duplicates(inplace=True)
df1.head()
# Out:
#   Rating              Date                        Taken Helpful  \
# 0      1    August 3, 2020  Taken for less than 1 month       5
# 1    NaN     March 2, 2020                          NaN      14
# 2     10  October 17, 2019      Taken for 1 to 6 months      20
# 3      2   October 8, 2019  Taken for less than 1 month       9
# 4     10      May 21, 2019      Taken for 5 to 10 years      28
#
#                                               Review    Drug Condition  \
# 0  “I have Microvascular Angina and am already on...  Ranexa    Angina
# 1  “Have been on Ranexa for 2 years after having ...  Ranexa    Angina
# 2  “Started Ranexa two months ago after experienc...  Ranexa    Angina
# 3  “Tried several drugs for angina ranexa gave me...  Ranexa    Angina
# 4  “I'm a 55 year old female who experienced earl...  Ranexa    Angina
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                143                   292                 30   oral
# 1                143                   292                 30   oral
# 2                143                   292                 30   oral
# 3                143                   292                 30   oral
# 4                143                   292                 30   oral

# %%
url_template = "https://www.drugs.com/comments/isosorbide-mononitrate/for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:28<00:00,  1.40s/it]

# %%
df2 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df2['Drug'] = 'Isosorbide mononitrate'
df2['Condition'] = 'Angina'
df2['Major Interaction'] = 8
df2['Moderate Interaction'] = 151
df2['Minor Interaction'] = 2
df2['Dosage'] = 'oral'
df2.drop_duplicates(inplace=True)
df2.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0      1   October 18, 2020  Taken for less than 1 month       1
# 1      1   October 13, 2020  Taken for less than 1 month       1
# 2      8    October 3, 2020                          NaN       1
# 3    NaN  September 8, 2020  Taken for less than 1 month       6
# 4      1      July 30, 2020  Taken for less than 1 month       4
#
#                                               Review                    Drug  \
# 0  “I was prescribed this medicine for high blood...  Isosorbide mononitrate
# 1  “The first day I tried this drug I became very...  Isosorbide mononitrate
# 2  “I am in so much pain and I've only taken 2 pi...  Isosorbide mononitrate
# 3  “Taken isosorbide mononitrate 30mg for 4 days....  Isosorbide mononitrate
# 4  “Prescribed isosorbide mononitrate for possibl...  Isosorbide mononitrate
#
#   Condition  Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0    Angina                  8                   151                  2   oral
# 1    Angina                  8                   151                  2   oral
# 2    Angina                  8                   151                  2   oral
# 3    Angina                  8                   151                  2   oral
# 4    Angina                  8                   151                  2   oral

# %%
url_template = "https://www.drugs.com/comments/metoprolol/for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:30<00:00,  1.51s/it]

# %%
df3 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df3['Drug'] = 'Metoprolol'
df3['Condition'] = 'Angina'
df3['Major Interaction'] = 22
df3['Moderate Interaction'] = 419
df3['Minor Interaction'] = 35
df3['Dosage'] = 'oral'
df3.drop_duplicates(inplace=True)
df3.head()
# Out:
#   Rating              Date                        Taken Helpful  \
# 0      1    March 10, 2020      Taken for 1 to 6 months      13
# 1      4  October 25, 2019  Taken for less than 1 month      23
# 2      9   August 28, 2019  Taken for less than 1 month      23
# 3      9     March 7, 2017                          NaN      21
# 4     10  January 25, 2017                          NaN      15
#
#                                               Review        Drug Condition  \
# 0  “Horrible horrible. Been on this tablet for ab...  Metoprolol    Angina
# 1  Metoprolol Succinate ER (metoprolol):\t\t\t“Ve...  Metoprolol    Angina
# 2  Metoprolol Tartrate (metoprolol):\t\t\t“I like...  Metoprolol    Angina
# 3  “This drug has literally changed my life in a ...  Metoprolol    Angina
# 4  “I had a quadruple bypass and I have been taki...  Metoprolol    Angina
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 22                   419                 35   oral
# 1                 22                   419                 35   oral
# 2                 22                   419                 35   oral
# 3                 22                   419                 35   oral
# 4                 22                   419                 35   oral

# %%
url_template = "https://www.drugs.com/comments/nitroglycerin/for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:27<00:00,  1.38s/it]

# %%
df4 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df4['Drug'] = 'Nitroglycerin'
df4['Condition'] = 'Angina'
df4['Major Interaction'] = 8
df4['Moderate Interaction'] = 169
df4['Minor Interaction'] = 28
df4['Dosage'] = 'oral'
df4.drop_duplicates(inplace=True)
df4.head()
# Out:
#   Rating               Date                       Taken Helpful  \
# 0      9     April 18, 2020  Taken for 10 years or more       2
# 1     10  February 24, 2016                         NaN      15
# 2      8     March 14, 2015      Taken for 2 to 5 years      27
# 3     10     March 27, 2012                         NaN      16
# 4      8      March 7, 2010                         NaN      99
#
#                                               Review           Drug Condition  \
# 0  Nitrolingual Pumpspray (nitroglycerin):\t\t\t“...  Nitroglycerin    Angina
# 1  “I have had heart disease for many years and a...  Nitroglycerin    Angina
# 2  Nitrostat (nitroglycerin):\t\t\t“There should ...  Nitroglycerin    Angina
# 3  “This spray is very effective in eradicating n...  Nitroglycerin    Angina
# 4  Nitrostat (nitroglycerin):\t\t\t“My cardiologi...  Nitroglycerin    Angina
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                  8                   169                 28   oral
# 1                  8                   169                 28   oral
# 2                  8                   169                 28   oral
# 3                  8                   169                 28   oral
# 4                  8                   169                 28   oral

# %%
url_template = "https://www.drugs.com/comments/isosorbide-dinitrate/for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:27<00:00,  1.39s/it]

# %%
df5 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df5['Drug'] = 'Isosorbide dinitrate'
df5['Condition'] = 'Angina'
df5['Major Interaction'] = 8
df5['Moderate Interaction'] = 151
df5['Minor Interaction'] = 2
df5['Dosage'] = 'oral'
df5.drop_duplicates(inplace=True)
df5.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0      1  November 26, 2019  Taken for less than 1 month       3
# 1      1    August 10, 2019                          NaN       4
# 2      4  December 19, 2010                          NaN      14
# 3      9     April 30, 2008                          NaN      31
#
#                                               Review                  Drug  \
# 0  “I was given this medication for very bad ches...  Isosorbide dinitrate
# 1  “A blood pressure med caused my heart rate to ...  Isosorbide dinitrate
# 2  “I have been using this medicine for a few mon...  Isosorbide dinitrate
# 3  “Made a substantial difference in my quality o...  Isosorbide dinitrate
#
#   Condition  Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0    Angina                  8                   151                  2   oral
# 1    Angina                  8                   151                  2   oral
# 2    Angina                  8                   151                  2   oral
# 3    Angina                  8                   151                  2   oral

# %%
url_template = "https://www.drugs.com/comments/carvedilol/for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:26<00:00,  1.34s/it]

# %%
df6 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df6['Drug'] = 'Carvedilol'
df6['Condition'] = 'Angina'
df6['Major Interaction'] = 43
df6['Moderate Interaction'] = 430
df6['Minor Interaction'] = 30
df6['Dosage'] = 'oral'
df6.drop_duplicates(inplace=True)
df6.head()
# Out:
#   Rating               Date                         Taken Helpful  \
# 0    NaN  December 10, 2017  Taken for 6 months to 1 year       6
# 1     10       July 2, 2017                           NaN       7
# 2      1  December 11, 2016                           NaN      12
#
#                                               Review        Drug Condition  \
# 0  “I started on 12 mg a day after MI.  Almost im...  Carvedilol    Angina
# 1  “Been on this for a year, smallest dose twice ...  Carvedilol    Angina
# 2  “Serious chest & joint pain. Headaches. Leg pain”  Carvedilol    Angina
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 43                   430                 30   oral
# 1                 43                   430                 30   oral
# 2                 43                   430                 30   oral

# %%
url_template = "https://www.drugs.com/comments/metoprolol/lopressor-for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:27<00:00,  1.37s/it]

# %%
df7 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df7['Drug'] = 'Lopressor'
df7['Condition'] = 'Angina'
df7['Major Interaction'] = 22
df7['Moderate Interaction'] = 419
df7['Minor Interaction'] = 35
df7['Dosage'] = 'oral'
df7.drop_duplicates(inplace=True)
df7.head()
# Out:
#   Rating                Date  Taken Helpful  \
# 0     10    January 31, 2010    NaN      23
# 1     10  September 30, 2009    NaN      50
# 2     10       June 30, 2009    NaN      47
#
#                                               Review       Drug Condition  \
# 0                                        “The best.”  Lopressor    Angina
# 1  “I have Angina and over the past year began a ...  Lopressor    Angina
# 2  “This medication helps more than anything I ha...  Lopressor    Angina
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 22                   419                 35   oral
# 1                 22                   419                 35   oral
# 2                 22                   419                 35   oral

# %%
url_template = "https://www.drugs.com/comments/nitroglycerin/nitrolingual-pumpspray-for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:27<00:00,  1.38s/it]

# %%
df8 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df8['Drug'] = 'Nitrolingual Pumpspray'
df8['Condition'] = 'Angina'
df8['Major Interaction'] = 8
df8['Moderate Interaction'] = 169
df8['Minor Interaction'] = 28
df8['Dosage'] = 'oral'
df8.drop_duplicates(inplace=True)
df8.head()
# Out:
#   Rating            Date                       Taken Helpful  \
# 0      9  April 18, 2020  Taken for 10 years or more       2
# 1      8    May 31, 2008                         NaN      41
# 2     10   April 3, 2008                         NaN      45
#
#                                               Review                    Drug  \
# 0  “I have used nitrolingual spray for about 10 y...  Nitrolingual Pumpspray
# 1  “It works great, especially for night pain.  H...  Nitrolingual Pumpspray
# 2  “Nitrolingual pumpspray is the best thing to c...  Nitrolingual Pumpspray
#
#   Condition  Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0    Angina                  8                   169                 28   oral
# 1    Angina                  8                   169                 28   oral
# 2    Angina                  8                   169                 28   oral

# %%
url_template = "https://www.drugs.com/comments/aspirin/for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:31<00:00,  1.56s/it]

# %%
df9 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df9['Drug'] = 'Aspirin'
df9['Condition'] = 'Angina'
df9['Major Interaction'] = 46
df9['Moderate Interaction'] = 226
df9['Minor Interaction'] = 46
df9['Dosage'] = 'oral'
df9.drop_duplicates(inplace=True)
df9.head()
# Out:
#   Rating                Date                    Taken Helpful  \
# 0     10    February 5, 2020  Taken for 5 to 10 years       4
# 1     10  September 17, 2009                      NaN      21
#
#                                               Review     Drug Condition  \
# 0  St. Joseph Aspirin (aspirin):\t\t\t“My doctor ...  Aspirin    Angina
# 1  Bayer Aspirin Extra Strength Plus (aspirin):\t...  Aspirin    Angina
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 46                   226                 46   oral
# 1                 46                   226                 46   oral

# %%
url_template = "https://www.drugs.com/comments/metoprolol/metoprolol-tartrate-for-angina-pectoris.html?page={}"
max_results_per_page = 20
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 20/20 [00:27<00:00,  1.36s/it]

# %%
df10 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df10['Drug'] = 'Metoprolol Tartrate'
df10['Condition'] = 'Angina'
df10['Major Interaction'] = 22
df10['Moderate Interaction'] = 419
df10['Minor Interaction'] = 35
df10['Dosage'] = 'oral'
df10.drop_duplicates(inplace=True)
df10.head()
# Out:
#   Rating             Date                        Taken Helpful  \
# 0      9  August 28, 2019  Taken for less than 1 month      23
# 1      1      May 8, 2016  Taken for less than 1 month      30
#
#                                               Review                 Drug  \
# 0  “I like this pill. It relaxes me. My blood pre...  Metoprolol Tartrate
# 1  “Extreme fatigue\r\nPressure in my head\r\nHea...  Metoprolol Tartrate
#
#   Condition  Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0    Angina                 22                   419                 35   oral
# 1    Angina                 22                   419                 35   oral

# %%
frames = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
df_angina = pd.concat(frames)

# %%
df_angina.reset_index(inplace=True, drop=True)

# %%
df_angina
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        1      August 3, 2020  Taken for less than 1 month       5
# 1      NaN       March 2, 2020                          NaN      14
# 2        8    February 9, 2020  Taken for less than 1 month       6
# 3       10    October 17, 2019      Taken for 1 to 6 months      20
# 4        2     October 8, 2019  Taken for less than 1 month       9
# ..     ...                 ...                          ...     ...
# 194     10       April 3, 2008                          NaN      45
# 195     10    February 5, 2020      Taken for 5 to 10 years       4
# 196     10  September 17, 2009                          NaN      21
# 197      9     August 28, 2019  Taken for less than 1 month      23
# 198      1         May 8, 2016  Taken for less than 1 month      30
#
#                                                 Review  \
# 0    Ranexa (ranolazine):\t\t\t“I have Microvascula...
# 1    Ranexa (ranolazine):\t\t\t“Have been on Ranexa...
# 2    “I'm a 62 yr old male. I had a heart attack 11...
# 3    Ranexa (ranolazine):\t\t\t“Started Ranexa two ...
# 4    Ranexa (ranolazine):\t\t\t“Tried several drugs...
# ..                                                 ...
# 194  “Nitrolingual pumpspray is the best thing to c...
# 195  St. Joseph Aspirin (aspirin):\t\t\t“My doctor ...
# 196  Bayer Aspirin Extra Strength Plus (aspirin):\t...
# 197  “I like this pill. It relaxes me. My blood pre...
# 198  “Extreme fatigue\r\nPressure in my head\r\nHea...
#
#                        Drug Condition  Major Interaction  \
# 0                Ranolazine    Angina                143
# 1                Ranolazine    Angina                143
# 2                Ranolazine    Angina                143
# 3                Ranolazine    Angina                143
# 4                Ranolazine    Angina                143
# ..                      ...       ...                ...
# 194  Nitrolingual Pumpspray    Angina                  8
# 195                 Aspirin    Angina                 46
# 196                 Aspirin    Angina                 46
# 197     Metoprolol Tartrate    Angina                 22
# 198     Metoprolol Tartrate    Angina                 22
#
#      Moderate Interaction  Minor Interaction Dosage
# 0                     292                 30   oral
# 1                     292                 30   oral
# 2                     292                 30   oral
# 3                     292                 30   oral
# 4                     292                 30   oral
# ..                    ...                ...    ...
# 194                   169                 28   oral
# 195                   226                 46   oral
# 196                   226                 46   oral
# 197                   419                 35   oral
# 198                   419                 35   oral
#
# [199 rows x 11 columns]

# %%
#save to CSV as master 
df_angina.to_csv("df_angina.csv")
