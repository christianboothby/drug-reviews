# %%
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm
from time import time, sleep

# %%
url_template = "https://www.drugs.com/comments/montelukast/for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:23<00:00,  1.60s/it]

# %%
df = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df['Drug'] = 'Montelukast'
df['Condition'] = 'Asthma'
df['Major Interaction'] = 0
df['Moderate Interaction'] = 84
df['Minor Interaction'] = 0
df['Dosage'] = 'oral'
df.drop_duplicates(inplace=True)
df
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        6    November 2, 2020       Taken for 2 to 5 years       4
# 1        8    October 30, 2020  Taken for less than 1 month       1
# 2        7  September 21, 2020  Taken for less than 1 month      11
# 3        9       July 30, 2020  Taken for less than 1 month       3
# 4        5       June 13, 2020       Taken for 2 to 5 years       8
# ..     ...                 ...                          ...     ...
# 174      1    November 9, 2009                          NaN      66
# 175      2    October 28, 2009                          NaN      22
# 176     10    October 16, 2009                          NaN      33
# 177      9   September 3, 2009                          NaN       8
# 178     10         May 8, 2009                          NaN      16
#
#                                                 Review         Drug Condition  \
# 0    Singulair (montelukast):\t\t\t“While on this m...  Montelukast    Asthma
# 1    “It works amazing.  In all my years of getting...  Montelukast    Asthma
# 2    “I have been on Singulair for a couple weeks a...  Montelukast    Asthma
# 3    “I started this drug as I developed asthma - l...  Montelukast    Asthma
# 4    “My son has been taking montelukast from age 3...  Montelukast    Asthma
# ..                                                 ...          ...       ...
# 174  Singulair (montelukast):\t\t\t“Great for the a...  Montelukast    Asthma
# 175  Singulair (montelukast):\t\t\t“I was taking Si...  Montelukast    Asthma
# 176  Singulair (montelukast):\t\t\t“I started takin...  Montelukast    Asthma
# 177  Singulair (montelukast):\t\t\t“This is a great...  Montelukast    Asthma
# 178  Singulair (montelukast):\t\t\t“It works excell...  Montelukast    Asthma
#
#      Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                    0                    84                  0   oral
# 1                    0                    84                  0   oral
# 2                    0                    84                  0   oral
# 3                    0                    84                  0   oral
# 4                    0                    84                  0   oral
# ..                 ...                   ...                ...    ...
# 174                  0                    84                  0   oral
# 175                  0                    84                  0   oral
# 176                  0                    84                  0   oral
# 177                  0                    84                  0   oral
# 178                  0                    84                  0   oral
#
# [154 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/fluticasone-vilanterol/breo-ellipta-for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:22<00:00,  1.50s/it]

# %%
df1 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df1['Drug'] = 'Breo Ellipta'
df1['Condition'] = 'Asthma'
df1['Major Interaction'] = 44
df1['Moderate Interaction'] = 346
df1['Minor Interaction'] = 17
df1['Dosage'] = 'oral'
df1.drop_duplicates(inplace=True)
df1
# Out:
#     Rating                Date                         Taken Helpful  \
# 0        9    October 13, 2020        Taken for 2 to 5 years       2
# 1       10     October 6, 2020   Taken for less than 1 month       1
# 2       10  September 23, 2020                           NaN       0
# 3       10     August 29, 2020        Taken for 1 to 2 years       1
# 4        2     August 18, 2020   Taken for less than 1 month       5
# ..     ...                 ...                           ...     ...
# 118     10    January 19, 2016       Taken for 1 to 6 months      23
# 119      1     January 2, 2016                           NaN      26
# 120     10   December 22, 2015                           NaN      18
# 121      6   December 13, 2015  Taken for 6 months to 1 year      17
# 122      2    October 29, 2015                           NaN      39
#
#                                                 Review          Drug  \
# 0    “Years ago, my doctor gave me a sample and a c...  Breo Ellipta
# 1    “Breo has been like a miracle for me. No more ...  Breo Ellipta
# 2    “I have used rescue puffers, but they didn't w...  Breo Ellipta
# 3    “I can’t believe all of these bad reviews. I’v...  Breo Ellipta
# 4    “Day 6 on Breo, today I had to use my rescue i...  Breo Ellipta
# ..                                                 ...           ...
# 118  “I am a 48 year old women who has had Asthma m...  Breo Ellipta
# 119  “Body aches, fever, chest pain, heavy chest, p...  Breo Ellipta
# 120  “Breo for asthma is once daily. Cutting dosing...  Breo Ellipta
# 121  “I could breathe better, but I lost my sense o...  Breo Ellipta
# 122  “I was changed to Breo almost 3 months ago, af...  Breo Ellipta
#
#     Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0      Asthma                 44                   346                 17
# 1      Asthma                 44                   346                 17
# 2      Asthma                 44                   346                 17
# 3      Asthma                 44                   346                 17
# 4      Asthma                 44                   346                 17
# ..        ...                ...                   ...                ...
# 118    Asthma                 44                   346                 17
# 119    Asthma                 44                   346                 17
# 120    Asthma                 44                   346                 17
# 121    Asthma                 44                   346                 17
# 122    Asthma                 44                   346                 17
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 118   oral
# 119   oral
# 120   oral
# 121   oral
# 122   oral
#
# [98 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/prednisone/for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:28<00:00,  1.93s/it]

# %%
df2 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df2['Drug'] = 'Prednisone'
df2['Condition'] = 'Asthma'
df2['Major Interaction'] = 55
df2['Moderate Interaction'] = 397
df2['Minor Interaction'] = 39
df2['Dosage'] = 'oral'
df2.drop_duplicates(inplace=True)
df2.head()
# Out:
#   Rating                Date                        Taken Helpful  \
# 0      9    October 21, 2020                          NaN       2
# 1     10  September 15, 2020  Taken for less than 1 month       5
# 2      5     August 18, 2020  Taken for less than 1 month       4
# 3     10      March 15, 2020  Taken for less than 1 month       2
# 4     10      March 14, 2020      Taken for 5 to 10 years       9
#
#                                               Review        Drug Condition  \
# 0  “I have been taking prednisone for asthma it m...  Prednisone    Asthma
# 1  “For me prednisone is a lifesaver, I have asth...  Prednisone    Asthma
# 2  “I was prescribed prednisone after the doctor ...  Prednisone    Asthma
# 3  “Had asthma last week Monday early morning, wa...  Prednisone    Asthma
# 4  “On prednisone at 20mg for 10 days fixes my wh...  Prednisone    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 55                   397                 39   oral
# 1                 55                   397                 39   oral
# 2                 55                   397                 39   oral
# 3                 55                   397                 39   oral
# 4                 55                   397                 39   oral

# %%
url_template = "https://www.drugs.com/comments/mepolizumab/for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:21<00:00,  1.43s/it]

# %%
df3 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df3['Drug'] = 'Mepolizumab'
df3['Condition'] = 'Asthma'
df3['Major Interaction'] = 0
df3['Moderate Interaction'] = 0
df3['Minor Interaction'] = 0
df3['Dosage'] = 'injection'
df3.drop_duplicates(inplace=True)
df3.head()
# Out:
#   Rating                Date                         Taken Helpful  \
# 0      9    October 26, 2020        Taken for 1 to 2 years       0
# 1     10  September 17, 2020                           NaN       2
# 2    NaN     August 23, 2020                           NaN       2
# 3      1     August 13, 2020       Taken for 1 to 6 months       3
# 4      1       June 14, 2020  Taken for 6 months to 1 year       7
#
#                                               Review         Drug Condition  \
# 0  Nucala (mepolizumab):\t\t\t“Until I started ta...  Mepolizumab    Asthma
# 1  Nucala (mepolizumab):\t\t\t“I am a very lucky ...  Mepolizumab    Asthma
# 2  Nucala (mepolizumab):\t\t\t“I have just starte...  Mepolizumab    Asthma
# 3  Nucala (mepolizumab):\t\t\t“I just had my 4th ...  Mepolizumab    Asthma
# 4  Nucala (mepolizumab):\t\t\t“I’ve had seven inj...  Mepolizumab    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                  0                     0                  0  injection
# 1                  0                     0                  0  injection
# 2                  0                     0                  0  injection
# 3                  0                     0                  0  injection
# 4                  0                     0                  0  injection

# %%
url_template = "https://www.drugs.com/comments/mepolizumab/nucala-for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:21<00:00,  1.43s/it]

# %%
df4 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df4['Drug'] = 'Nucala'
df4['Condition'] = 'Asthma'
df4['Major Interaction'] = 0
df4['Moderate Interaction'] = 0
df4['Minor Interaction'] = 0
df4['Dosage'] = 'injection'
df4.drop_duplicates(inplace=True)
df4.head()
# Out:
#   Rating                Date                         Taken Helpful  \
# 0      9    October 26, 2020        Taken for 1 to 2 years       0
# 1     10  September 17, 2020                           NaN       2
# 2    NaN     August 23, 2020                           NaN       2
# 3      1     August 13, 2020       Taken for 1 to 6 months       3
# 4      1       June 14, 2020  Taken for 6 months to 1 year       7
#
#                                               Review    Drug Condition  \
# 0  “Until I started taking Nacala, my asthma was ...  Nucala    Asthma
# 1  “I am a very lucky lady.  Nucala has been fant...  Nucala    Asthma
# 2  “I have just started Nucala  after being on fa...  Nucala    Asthma
# 3  “I just had my 4th Nucala shot.I am not impres...  Nucala    Asthma
# 4  “I’ve had seven injections and have had an ast...  Nucala    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                  0                     0                  0  injection
# 1                  0                     0                  0  injection
# 2                  0                     0                  0  injection
# 3                  0                     0                  0  injection
# 4                  0                     0                  0  injection

# %%
url_template = "https://www.drugs.com/comments/formoterol-mometasone/dulera-for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:20<00:00,  1.38s/it]

# %%
df5 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df5['Drug'] = 'Dulera'
df5['Condition'] = 'Asthma'
df5['Major Interaction'] = 21
df5['Moderate Interaction'] = 360
df5['Minor Interaction'] = 17
df5['Dosage'] = 'aerosol'
df5.drop_duplicates(inplace=True)
df5.head()
# Out:
#   Rating                Date                        Taken Helpful  \
# 0      1  September 17, 2020  Taken for less than 1 month       0
# 1     10      March 23, 2020       Taken for 2 to 5 years       8
# 2      2      March 22, 2020  Taken for less than 1 month       4
# 3    NaN   February 27, 2020  Taken for less than 1 month       7
# 4     10     January 4, 2020       Taken for 1 to 2 years       2
#
#                                               Review    Drug Condition  \
# 0  “Put it to my mouth\nPushed the inhaler releas...  Dulera    Asthma
# 1  “I've suffered from asthma since childhood and...  Dulera    Asthma
# 2  “After an asthma attack a month ago. A doctor ...  Dulera    Asthma
# 3  “I suffered with asthma my entire life, and wa...  Dulera    Asthma
# 4  “I've had asthma my entire life to the point I...  Dulera    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction   Dosage
# 0                 21                   360                 17  aerosol
# 1                 21                   360                 17  aerosol
# 2                 21                   360                 17  aerosol
# 3                 21                   360                 17  aerosol
# 4                 21                   360                 17  aerosol

# %%
url_template = "https://www.drugs.com/comments/benralizumab/for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:20<00:00,  1.39s/it]

# %%
df6 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df6['Drug'] = 'Benralizumab'
df6['Condition'] = 'Asthma'
df6['Major Interaction'] = 0
df6['Moderate Interaction'] = 0
df6['Minor Interaction'] = 0
df6['Dosage'] = 'injection'
df6.drop_duplicates(inplace=True)
df6.head()
# Out:
#   Rating                Date                         Taken Helpful  \
# 0     10    November 1, 2020  Taken for 6 months to 1 year       2
# 1      8  September 30, 2020        Taken for 1 to 2 years       8
# 2      1  September 14, 2020                           NaN       3
# 3      3       July 26, 2020       Taken for 1 to 6 months       7
# 4      5       July 22, 2020                           NaN       7
#
#                                               Review          Drug Condition  \
# 0  Fasenra (benralizumab):\t\t\t“I am 62 years ol...  Benralizumab    Asthma
# 1  Fasenra (benralizumab):\t\t\t“I developed EGPA...  Benralizumab    Asthma
# 2  Fasenra (benralizumab):\t\t\t“Had the first Fa...  Benralizumab    Asthma
# 3  Fasenra (benralizumab):\t\t\t“I’ve been on Fas...  Benralizumab    Asthma
# 4  Fasenra (benralizumab):\t\t\t“I feel tired aft...  Benralizumab    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                  0                     0                  0  injection
# 1                  0                     0                  0  injection
# 2                  0                     0                  0  injection
# 3                  0                     0                  0  injection
# 4                  0                     0                  0  injection

# %%
url_template = "https://www.drugs.com/comments/benralizumab/fasenra-for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:20<00:00,  1.40s/it]

# %%
df7 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df7['Drug'] = 'Fasenra'
df7['Condition'] = 'Asthma'
df7['Major Interaction'] = 0
df7['Moderate Interaction'] = 0
df7['Minor Interaction'] = 0
df7['Dosage'] = 'injection'
df7.drop_duplicates(inplace=True)
df7.head()
# Out:
#   Rating                Date                         Taken Helpful  \
# 0     10    November 1, 2020  Taken for 6 months to 1 year       2
# 1      8  September 30, 2020        Taken for 1 to 2 years       8
# 2      1  September 14, 2020                           NaN       3
# 3      3       July 26, 2020       Taken for 1 to 6 months       7
# 4      5       July 22, 2020                           NaN       7
#
#                                               Review     Drug Condition  \
# 0  “I am 62 years old and had asthma all my life....  Fasenra    Asthma
# 1  “I developed EGPA (Eosinophilic granulomatosis...  Fasenra    Asthma
# 2  “Had the first Fasenra injection two weeks ago...  Fasenra    Asthma
# 3  “I’ve been on Fasenra for about 4 months for a...  Fasenra    Asthma
# 4  “I feel tired after the Fasenra injection and ...  Fasenra    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                  0                     0                  0  injection
# 1                  0                     0                  0  injection
# 2                  0                     0                  0  injection
# 3                  0                     0                  0  injection
# 4                  0                     0                  0  injection

# %%
url_template = "https://www.drugs.com/comments/ipratropium/for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:20<00:00,  1.39s/it]

# %%
df8 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df8['Drug'] = 'Ipratropium'
df8['Condition'] = 'Asthma'
df8['Major Interaction'] = 0
df8['Moderate Interaction'] = 100
df8['Minor Interaction'] = 1
df8['Dosage'] = 'aerosol'
df8.drop_duplicates(inplace=True)
df8.head()
# Out:
#   Rating                Date                        Taken Helpful  \
# 0      1   December 27, 2019                          NaN       1
# 1      3         May 1, 2019  Taken for less than 1 month       1
# 2    NaN     January 6, 2019      Taken for 5 to 10 years       8
# 3    NaN  September 29, 2016                          NaN      10
# 4      9    January 12, 2013      Taken for 5 to 10 years      16
#
#                                               Review         Drug Condition  \
# 0  “Was given this drug in combination with albut...  Ipratropium    Asthma
# 1  “My 3 year old has asthma, and we have been at...  Ipratropium    Asthma
# 2  Atrovent (ipratropium):\t\t\t“I use both the n...  Ipratropium    Asthma
# 3  Atrovent (ipratropium):\t\t\t“This works SO mu...  Ipratropium    Asthma
# 4  Atrovent (ipratropium):\t\t\t“I also take Sere...  Ipratropium    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction   Dosage
# 0                  0                   100                  1  aerosol
# 1                  0                   100                  1  aerosol
# 2                  0                   100                  1  aerosol
# 3                  0                   100                  1  aerosol
# 4                  0                   100                  1  aerosol

# %%
url_template = "https://www.drugs.com/comments/reslizumab/cinqair-for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:20<00:00,  1.38s/it]

# %%
df9 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df9['Drug'] = 'Cinqair'
df9['Condition'] = 'Asthma'
df9['Major Interaction'] = 0
df9['Moderate Interaction'] = 0
df9['Minor Interaction'] = 0
df9['Dosage'] = 'injection'
df9.drop_duplicates(inplace=True)
df9.head()
# Out:
#   Rating               Date                         Taken Helpful  \
# 0     10      March 9, 2019        Taken for 1 to 2 years       1
# 1      7  December 27, 2018       Taken for 1 to 6 months       0
# 2      8  December 21, 2018  Taken for 6 months to 1 year       1
# 3     10     March 11, 2018       Taken for 1 to 6 months       0
# 4      8      March 7, 2018  Taken for 6 months to 1 year       0
#
#                                               Review     Drug Condition  \
# 0  “I have been taking Cinqair infusions for two ...  Cinqair    Asthma
# 1  “I have had two injections so far. I am in the...  Cinqair    Asthma
# 2  “I just had my 12th infusion to treat asthma t...  Cinqair    Asthma
# 3  “My eosinophil count was very high. Asthma was...  Cinqair    Asthma
# 4  “Asthma now under control.\n. My side effects ...  Cinqair    Asthma
#
#    Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                  0                     0                  0  injection
# 1                  0                     0                  0  injection
# 2                  0                     0                  0  injection
# 3                  0                     0                  0  injection
# 4                  0                     0                  0  injection

# %%
url_template = "https://www.drugs.com/comments/methylprednisolone/for-asthma.html?page={}"
max_results_per_page = 15
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 15/15 [00:24<00:00,  1.64s/it]

# %%
df10 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df10['Drug'] = 'Methylprednisolone'
df10['Condition'] = 'Asthma'
df10['Major Interaction'] = 79
df10['Moderate Interaction'] = 373
df10['Minor Interaction'] = 37
df10['Dosage'] = 'oral'
df10.drop_duplicates(inplace=True)
df10.head()
# Out:
#   Rating              Date                         Taken Helpful  \
# 0      8   October 2, 2020   Taken for less than 1 month       2
# 1     10     June 18, 2020  Taken for 6 months to 1 year       2
# 2    NaN    April 10, 2020   Taken for less than 1 month       7
# 3      1      May 25, 2019   Taken for less than 1 month       9
# 4     10  January 29, 2015                           NaN       7
#
#                                               Review                Drug  \
# 0  Medrol Dosepak (methylprednisolone):\t\t\t“Thi...  Methylprednisolone
# 1  MethylPREDNISolone Dose Pack (methylprednisolo...  Methylprednisolone
# 2  MethylPREDNISolone Dose Pack (methylprednisolo...  Methylprednisolone
# 3  “I've been taking the methylprednisolone dose ...  Methylprednisolone
# 4  Solu-Medrol (methylprednisolone):\t\t\t“Great ...  Methylprednisolone
#
#   Condition  Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0    Asthma                 79                   373                 37   oral
# 1    Asthma                 79                   373                 37   oral
# 2    Asthma                 79                   373                 37   oral
# 3    Asthma                 79                   373                 37   oral
# 4    Asthma                 79                   373                 37   oral

# %%
frames = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
df_asthma = pd.concat(frames)

# %%
df_asthma.reset_index(inplace=True, drop=True)

# %%
df_asthma
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        6    November 2, 2020       Taken for 2 to 5 years       4
# 1        8    October 30, 2020  Taken for less than 1 month       1
# 2        7  September 21, 2020  Taken for less than 1 month      11
# 3        9       July 30, 2020  Taken for less than 1 month       3
# 4        5       June 13, 2020       Taken for 2 to 5 years       8
# ..     ...                 ...                          ...     ...
# 482      1        May 25, 2019  Taken for less than 1 month       9
# 483     10    January 29, 2015                          NaN       7
# 484      9       March 6, 2013                          NaN      18
# 485      6    January 23, 2010                          NaN       9
# 486      9       March 5, 2009                          NaN      22
#
#                                                 Review                Drug  \
# 0    Singulair (montelukast):\t\t\t“While on this m...         Montelukast
# 1    “It works amazing.  In all my years of getting...         Montelukast
# 2    “I have been on Singulair for a couple weeks a...         Montelukast
# 3    “I started this drug as I developed asthma - l...         Montelukast
# 4    “My son has been taking montelukast from age 3...         Montelukast
# ..                                                 ...                 ...
# 482  “I've been taking the methylprednisolone dose ...  Methylprednisolone
# 483  Solu-Medrol (methylprednisolone):\t\t\t“Great ...  Methylprednisolone
# 484  MethylPREDNISolone Dose Pack (methylprednisolo...  Methylprednisolone
# 485  Solu-Medrol (methylprednisolone):\t\t\t“My ast...  Methylprednisolone
# 486  Medrol Dosepak (methylprednisolone):\t\t\t“Wor...  Methylprednisolone
#
#     Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0      Asthma                  0                    84                  0
# 1      Asthma                  0                    84                  0
# 2      Asthma                  0                    84                  0
# 3      Asthma                  0                    84                  0
# 4      Asthma                  0                    84                  0
# ..        ...                ...                   ...                ...
# 482    Asthma                 79                   373                 37
# 483    Asthma                 79                   373                 37
# 484    Asthma                 79                   373                 37
# 485    Asthma                 79                   373                 37
# 486    Asthma                 79                   373                 37
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 482   oral
# 483   oral
# 484   oral
# 485   oral
# 486   oral
#
# [487 rows x 11 columns]

# %%
#save to CSV as master 
df_asthma.to_csv("df_asthma.csv")
