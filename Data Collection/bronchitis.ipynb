# %%
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm
from time import time, sleep

# %%
url_template = "https://www.drugs.com/comments/azithromycin/for-bronchitis.html.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:14<00:00,  1.60s/it]

# %%
df = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df['Drug'] = 'Azithromycin'
df['Condition'] = 'Bronchitis'
df['Major Interaction'] = 68
df['Moderate Interaction'] = 230
df['Minor Interaction'] = 21
df['Dosage'] = 'oral'
df.drop_duplicates(inplace=True)
df.head()
# Out:
#   Rating                Date                        Taken Helpful  \
# 0      9    October 24, 2020                          NaN       1
# 1     10    October 14, 2020  Taken for less than 1 month       1
# 2      9    October 13, 2020  Taken for less than 1 month       2
# 3      5     October 7, 2020  Taken for less than 1 month       0
# 4      1  September 22, 2020   Taken for 10 years or more       0
#
#                                               Review          Drug  \
# 0  For Chlamydia Infection:\t\t\t“My boyfriend sl...  Azithromycin
# 1  Z-Pak (azithromycin) for Bacterial Infection:\...  Azithromycin
# 2  For Chlamydia Infection:\t\t\t“Okay the review...  Azithromycin
# 3  Azithromycin Dose Pack (azithromycin) for Uppe...  Azithromycin
# 4  Azithromycin Dose Pack (azithromycin) for Sinu...  Azithromycin
#
#     Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0  Bronchitis                 68                   230                 21
# 1  Bronchitis                 68                   230                 21
# 2  Bronchitis                 68                   230                 21
# 3  Bronchitis                 68                   230                 21
# 4  Bronchitis                 68                   230                 21
#
#   Dosage
# 0   oral
# 1   oral
# 2   oral
# 3   oral
# 4   oral

# %%
url_template = "https://www.drugs.com/comments/clarithromycin/for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:16<00:00,  1.85s/it]

# %%
df1 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df1['Drug'] = 'Clarithromycin'
df1['Condition'] = 'Bronchitis'
df1['Major Interaction'] = 199
df1['Moderate Interaction'] = 369
df1['Minor Interaction'] = 48
df1['Dosage'] = 'oral'
df1.drop_duplicates(inplace=True)
df1.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0     10    August 31, 2020                          NaN       1
# 1      1        May 5, 2020                          NaN       8
# 2     10     April 29, 2020  Taken for less than 1 month       4
# 3      8     March 11, 2020  Taken for less than 1 month       5
# 4      3  February 25, 2020                          NaN       6
#
#                                               Review            Drug  \
# 0  “clarithromycin best antibiotic I've ever had ...  Clarithromycin
# 1  “Throwing these clarithromycin in the garbage!...  Clarithromycin
# 2  “I have been using this medicine (clarithromyc...  Clarithromycin
# 3  “On clarithromycin for bronchitis  only side e...  Clarithromycin
# 4  “Thankfully I’m on my last day of taking Clari...  Clarithromycin
#
#     Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0  Bronchitis                199                   369                 48
# 1  Bronchitis                199                   369                 48
# 2  Bronchitis                199                   369                 48
# 3  Bronchitis                199                   369                 48
# 4  Bronchitis                199                   369                 48
#
#   Dosage
# 0   oral
# 1   oral
# 2   oral
# 3   oral
# 4   oral

# %%
url_template = "https://www.drugs.com/comments/levofloxacin/for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:15<00:00,  1.77s/it]

# %%
df2 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df2['Drug'] = 'Levofloxacin'
df2['Condition'] = 'Bronchitis'
df2['Major Interaction'] = 103
df2['Moderate Interaction'] = 295
df2['Minor Interaction'] = 51
df2['Dosage'] = 'oral'
df2.drop_duplicates(inplace=True)
df2.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0     10       May 20, 2020  Taken for less than 1 month       3
# 1      1       May 20, 2020  Taken for less than 1 month       0
# 2      1     April 27, 2020  Taken for less than 1 month       5
# 3     10     April 11, 2020                          NaN       3
# 4     10  February 24, 2020   Taken for 10 years or more       4
#
#                                               Review          Drug  \
# 0  “Went to Dr. because I developed Bronchitis a ...  Levofloxacin
# 1  “My MD prescribed 500 mg levofloxacin.  Took 5...  Levofloxacin
# 2  “After 2 levofloxacin pills,  I had ruptured b...  Levofloxacin
# 3  Levaquin (levofloxacin):\t\t\t“Powerful result...  Levofloxacin
# 4  “Have been prescibed this many times over many...  Levofloxacin
#
#     Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0  Bronchitis                103                   295                 51
# 1  Bronchitis                103                   295                 51
# 2  Bronchitis                103                   295                 51
# 3  Bronchitis                103                   295                 51
# 4  Bronchitis                103                   295                 51
#
#   Dosage
# 0   oral
# 1   oral
# 2   oral
# 3   oral
# 4   oral

# %%
url_template = "https://www.drugs.com/comments/levofloxacin/levaquin-for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:15<00:00,  1.70s/it]

# %%
df3 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df3['Drug'] = 'Levaquin'
df3['Condition'] = 'Bronchitis'
df3['Major Interaction'] = 103
df3['Moderate Interaction'] = 295
df3['Minor Interaction'] = 51
df3['Dosage'] = 'oral'
df3.drop_duplicates(inplace=True)
df3.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0     10     April 11, 2020                          NaN       3
# 1      1   January 24, 2020                          NaN      12
# 2     10    January 7, 2020  Taken for less than 1 month      10
# 3     10  December 21, 2019       Taken for 2 to 5 years       7
# 4      1   October 25, 2019  Taken for less than 1 month      10
#
#                                               Review      Drug   Condition  \
# 0  “Powerful results for my sinus and bronchitis,...  Levaquin  Bronchitis
# 1  “After a bout with Levaquin and fluroquinolone...  Levaquin  Bronchitis
# 2  “Suffered from severe Bronchitis, involving mu...  Levaquin  Bronchitis
# 3  “This is the only antibiotics my body can take...  Levaquin  Bronchitis
# 4  “I am disable with severe neuropathies because...  Levaquin  Bronchitis
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                103                   295                 51   oral
# 1                103                   295                 51   oral
# 2                103                   295                 51   oral
# 3                103                   295                 51   oral
# 4                103                   295                 51   oral

# %%
url_template = "https://www.drugs.com/comments/guaifenesin/for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:14<00:00,  1.58s/it]

# %%
df4 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df4['Drug'] = 'Guaifenesin'
df4['Condition'] = 'Bronchitis'
df4['Major Interaction'] = 0
df4['Moderate Interaction'] = 0
df4['Minor Interaction'] = 0
df4['Dosage'] = 'oral'
df4.drop_duplicates(inplace=True)
df4.head()
# Out:
#   Rating                Date                        Taken Helpful  \
# 0      3  September 23, 2020  Taken for less than 1 month       2
# 1      1     August 20, 2020  Taken for less than 1 month       5
# 2      1       July 31, 2020  Taken for less than 1 month       3
# 3      9       April 4, 2020      Taken for 5 to 10 years       7
# 4      3      March 31, 2020  Taken for less than 1 month       4
#
#                                               Review         Drug   Condition  \
# 0  Mucinex (guaifenesin):\t\t\t“Although Mucinex ...  Guaifenesin  Bronchitis
# 1  Mucinex (guaifenesin):\t\t\t“I began a cough 4...  Guaifenesin  Bronchitis
# 2  Mucinex (guaifenesin):\t\t\t“mucinex night tim...  Guaifenesin  Bronchitis
# 3  Robafen (guaifenesin):\t\t\t“Have your local c...  Guaifenesin  Bronchitis
# 4  Mucinex (guaifenesin):\t\t\t“I'm on my second ...  Guaifenesin  Bronchitis
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                  0                     0                  0   oral
# 1                  0                     0                  0   oral
# 2                  0                     0                  0   oral
# 3                  0                     0                  0   oral
# 4                  0                     0                  0   oral

# %%
url_template = "https://www.drugs.com/comments/amoxicillin-clavulanate/for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:15<00:00,  1.68s/it]

# %%
df5 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df5['Drug'] = 'Amoxicillin/clavulanate'
df5['Condition'] = 'Bronchitis'
df5['Major Interaction'] = 9
df5['Moderate Interaction'] = 45
df5['Minor Interaction'] = 8
df5['Dosage'] = 'oral'
df5.drop_duplicates(inplace=True)
df5.head()
# Out:
#   Rating              Date                        Taken Helpful  \
# 0     10   October 8, 2020                          NaN       1
# 1     10     March 2, 2020  Taken for less than 1 month      16
# 2      1  October 14, 2019  Taken for less than 1 month       6
# 3      1   August 10, 2019  Taken for less than 1 month       1
# 4     10    April 16, 2019  Taken for less than 1 month      10
#
#                                               Review                     Drug  \
# 0  “Day two, and it's working so well, I had to q...  Amoxicillin/clavulanate
# 1  Augmentin (amoxicillin / clavulanate):\t\t\t“H...  Amoxicillin/clavulanate
# 2  Augmentin (amoxicillin / clavulanate):\t\t\t“D...  Amoxicillin/clavulanate
# 3  “This drug caused me to have diarrhea for mont...  Amoxicillin/clavulanate
# 4  Augmentin (amoxicillin / clavulanate):\t\t\t“T...  Amoxicillin/clavulanate
#
#     Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0  Bronchitis                  9                    45                  8
# 1  Bronchitis                  9                    45                  8
# 2  Bronchitis                  9                    45                  8
# 3  Bronchitis                  9                    45                  8
# 4  Bronchitis                  9                    45                  8
#
#   Dosage
# 0   oral
# 1   oral
# 2   oral
# 3   oral
# 4   oral

# %%
url_template = "https://www.drugs.com/comments/guaifenesin/mucinex-for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:15<00:00,  1.73s/it]

# %%
df6 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df6['Drug'] = 'Mucinex'
df6['Condition'] = 'Bronchitis'
df6['Major Interaction'] = 0
df6['Moderate Interaction'] = 0
df6['Minor Interaction'] = 0
df6['Dosage'] = 'oral'
df6.drop_duplicates(inplace=True)
df6.head()
# Out:
#   Rating                Date                        Taken Helpful  \
# 0      3  September 23, 2020  Taken for less than 1 month       2
# 1      1     August 20, 2020  Taken for less than 1 month       5
# 2      1       July 31, 2020  Taken for less than 1 month       3
# 3      3      March 31, 2020  Taken for less than 1 month       4
# 4      1      March 17, 2020                          NaN       4
#
#                                               Review     Drug   Condition  \
# 0  “Although Mucinex contains the exact same drug...  Mucinex  Bronchitis
# 1  “I began a cough 4 weeks ago. Then the mucus s...  Mucinex  Bronchitis
# 2        “mucinex night time doesn't work for COVID”  Mucinex  Bronchitis
# 3  “I'm on my second box of mucinex and really ha...  Mucinex  Bronchitis
# 4  “I took Mucinex about a month ago and it had m...  Mucinex  Bronchitis
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                  0                     0                  0   oral
# 1                  0                     0                  0   oral
# 2                  0                     0                  0   oral
# 3                  0                     0                  0   oral
# 4                  0                     0                  0   oral

# %%
url_template = "https://www.drugs.com/comments/doxycycline/for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:15<00:00,  1.77s/it]

# %%
df7 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df7['Drug'] = 'Doxycycline'
df7['Condition'] = 'Bronchitis'
df7['Major Interaction'] = 13
df7['Moderate Interaction'] = 146
df7['Minor Interaction'] = 30
df7['Dosage'] = 'oral'
df7.drop_duplicates(inplace=True)
df7.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0      9  February 18, 2020  Taken for less than 1 month       8
# 1      1  February 17, 2020  Taken for less than 1 month       5
# 2      1  December 31, 2019                          NaN      13
# 3      3   October 21, 2019  Taken for less than 1 month      13
# 4      3   October 13, 2019  Taken for less than 1 month      14
#
#                                               Review         Drug   Condition  \
# 0  “Took 100mg once per day for 6 days with 200mg...  Doxycycline  Bronchitis
# 1  “I started taking this drug for upper respirat...  Doxycycline  Bronchitis
# 2  “Took after 8 days of doxycycline for an  unre...  Doxycycline  Bronchitis
# 3  “I was prescribed this for bronchitis. And eve...  Doxycycline  Bronchitis
# 4  “doxycycline had little effect on treating the...  Doxycycline  Bronchitis
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 13                   146                 30   oral
# 1                 13                   146                 30   oral
# 2                 13                   146                 30   oral
# 3                 13                   146                 30   oral
# 4                 13                   146                 30   oral

# %%
url_template = "https://www.drugs.com/comments/cefdinir/for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:13<00:00,  1.48s/it]

# %%
df8 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df8['Drug'] = 'Cefdinir'
df8['Condition'] = 'Bronchitis'
df8['Major Interaction'] = 3
df8['Moderate Interaction'] = 40
df8['Minor Interaction'] = 0
df8['Dosage'] = 'oral'
df8.drop_duplicates(inplace=True)
df8.head()
# Out:
#   Rating                Date                        Taken Helpful  \
# 0      9  September 27, 2020  Taken for less than 1 month       1
# 1      1     January 3, 2020                          NaN       3
# 2      9   December 28, 2019                          NaN       5
# 3      6    November 3, 2019  Taken for less than 1 month       0
# 4      4    October 26, 2019                          NaN       5
#
#                                               Review      Drug   Condition  \
# 0  “On cefdinir 300mg twice daily. I had a sinus ...  Cefdinir  Bronchitis
# 1      “This did absolutely nothing for bronchitis.”  Cefdinir  Bronchitis
# 2  “I am a fair skinned red head and react to alm...  Cefdinir  Bronchitis
# 3  “Day 9 on cefdinir for bronchitis and I am sti...  Cefdinir  Bronchitis
# 4  “Took medication less than hour later chest pa...  Cefdinir  Bronchitis
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                  3                    40                  0   oral
# 1                  3                    40                  0   oral
# 2                  3                    40                  0   oral
# 3                  3                    40                  0   oral
# 4                  3                    40                  0   oral

# %%
url_template = "https://www.drugs.com/comments/azithromycin/zithromax-for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:14<00:00,  1.63s/it]

# %%
df9 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df9['Drug'] = 'Zithromax'
df9['Condition'] = 'Bronchitis'
df9['Major Interaction'] = 68
df9['Moderate Interaction'] = 230
df9['Minor Interaction'] = 21
df9['Dosage'] = 'oral'
df9.drop_duplicates(inplace=True)
df9.head()
# Out:
#   Rating              Date                        Taken Helpful  \
# 0      1  January 16, 2020  Taken for less than 1 month       8
# 1      1    August 1, 2019                          NaN      15
# 2      1   January 8, 2019  Taken for less than 1 month      16
# 3      1      May 31, 2018  Taken for less than 1 month       9
# 4      1     March 7, 2018  Taken for less than 1 month      10
#
#                                               Review       Drug   Condition  \
# 0  “I would be very careful taking this antibioti...  Zithromax  Bronchitis
# 1  “Zithromax is one of the worst medications I h...  Zithromax  Bronchitis
# 2  “I took a total of two doses: two caplets day ...  Zithromax  Bronchitis
# 3  “Diagnosed with bronchitis on Friday, started ...  Zithromax  Bronchitis
# 4  “I was diagnosed with bronchitis (even though ...  Zithromax  Bronchitis
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 68                   230                 21   oral
# 1                 68                   230                 21   oral
# 2                 68                   230                 21   oral
# 3                 68                   230                 21   oral
# 4                 68                   230                 21   oral

# %%
url_template = "https://www.drugs.com/comments/amoxicillin-clavulanate/augmentin-for-bronchitis.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:13<00:00,  1.56s/it]

# %%
df10 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df10['Drug'] = 'Augmentin'
df10['Condition'] = 'Bronchitis'
df10['Major Interaction'] = 9
df10['Moderate Interaction'] = 45
df10['Minor Interaction'] = 8
df10['Dosage'] = 'oral'
df10.drop_duplicates(inplace=True)
df10.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0     10      March 2, 2020  Taken for less than 1 month      16
# 1      1   October 14, 2019  Taken for less than 1 month       6
# 2     10     April 16, 2019  Taken for less than 1 month      10
# 3      1    January 5, 2019  Taken for less than 1 month       2
# 4      1  December 29, 2018  Taken for less than 1 month       1
#
#                                               Review       Drug   Condition  \
# 0  “Hit with a sore throat, cough etc...thought i...  Augmentin  Bronchitis
# 1  “Danny, I am dealing with the same issue.  Hav...  Augmentin  Bronchitis
# 2  “This antibiotic is the best when it comes to ...  Augmentin  Bronchitis
# 3  “Horrible allergic rash that is still visible ...  Augmentin  Bronchitis
# 4  “I don't know how effective this is but I do k...  Augmentin  Bronchitis
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                  9                    45                  8   oral
# 1                  9                    45                  8   oral
# 2                  9                    45                  8   oral
# 3                  9                    45                  8   oral
# 4                  9                    45                  8   oral

# %%
frames = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
df_bronchitis = pd.concat(frames)

# %%
df_bronchitis.reset_index(inplace=True, drop=True)

# %%
#save to CSV as master 
df_bronchitis.to_csv("df_bronchitis.csv")
