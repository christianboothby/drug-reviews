# %%
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm
from time import time, sleep

# %%
url_template = "https://www.drugs.com/comments/isotretinoin/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [00:46<00:00,  1.18s/it]

# %%
df = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df['Drug'] = 'isotretinoin'
df['Condition'] = 'Acne'
df['Major Interaction'] = 19
df['Moderate Interaction'] = 82
df['Minor Interaction'] = 0
df['Dosage'] = 'oral'
df.drop_duplicates(inplace=True)
df
# Out:
#     Rating                Date                         Taken Helpful  \
# 0        1  September 18, 2020       Taken for 1 to 6 months      19
# 1       10   September 5, 2020                           NaN       6
# 2        2     August 25, 2020  Taken for 6 months to 1 year       9
# 3       10     August 22, 2020  Taken for 6 months to 1 year       9
# 4        3     August 22, 2020       Taken for 1 to 6 months       9
# ..     ...                 ...                           ...     ...
# 953    NaN    February 8, 2008                           NaN      45
# 954    NaN    January 12, 2008                           NaN      51
# 955    NaN     January 6, 2008                           NaN      39
# 956    NaN   December 21, 2007                           NaN      61
# 957    NaN        July 9, 2007                           NaN      83
#
#                                                 Review          Drug  \
# 0    Accutane (isotretinoin):\t\t\t“I TOOK THIS POI...  isotretinoin
# 1    Myorisan (isotretinoin):\t\t\t“This is my sixt...  isotretinoin
# 2    Accutane (isotretinoin):\t\t\t“There is no dou...  isotretinoin
# 3    Claravis (isotretinoin):\t\t\t“A month after f...  isotretinoin
# 4    Accutane (isotretinoin):\t\t\t“I took this hor...  isotretinoin
# ..                                                 ...           ...
# 953  Accutane (isotretinoin):\t\t\t“I am just finis...  isotretinoin
# 954  Accutane (isotretinoin):\t\t\t“Accutane seems ...  isotretinoin
# 955  Accutane (isotretinoin):\t\t\t“My skin did imp...  isotretinoin
# 956  Claravis (isotretinoin):\t\t\t“I started takin...  isotretinoin
# 957  Accutane (isotretinoin):\t\t\t“Like the info s...  isotretinoin
#
#     Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0        Acne                 19                    82                  0
# 1        Acne                 19                    82                  0
# 2        Acne                 19                    82                  0
# 3        Acne                 19                    82                  0
# 4        Acne                 19                    82                  0
# ..        ...                ...                   ...                ...
# 953      Acne                 19                    82                  0
# 954      Acne                 19                    82                  0
# 955      Acne                 19                    82                  0
# 956      Acne                 19                    82                  0
# 957      Acne                 19                    82                  0
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 953   oral
# 954   oral
# 955   oral
# 956   oral
# 957   oral
#
# [933 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/adapalene-benzoyl-peroxide-topical/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [00:46<00:00,  1.18s/it]

# %%
df1 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df1['Drug'] = 'Adapalene / benzoyl peroxide'
df1['Condition'] = 'Acne'
df1['Major Interaction'] = 1
df1['Moderate Interaction'] = 12
df1['Minor Interaction'] = 1
df1['Dosage'] = 'topical gel'
df1.drop_duplicates(inplace=True)
df1
# Out:
#     Rating                Date                        Taken Helpful  \
# 0       10    October 27, 2020                          NaN       2
# 1       10    October 25, 2020                          NaN       2
# 2        9    October 19, 2020                          NaN       2
# 3       10    October 16, 2020                          NaN       1
# 4        1  September 30, 2020  Taken for less than 1 month       4
# ..     ...                 ...                          ...     ...
# 852      1     January 2, 2010                          NaN      18
# 853    NaN   November 27, 2009                          NaN      45
# 854      2   November 20, 2009                          NaN      17
# 855      9  September 27, 2009                          NaN      60
# 856      9        July 6, 2009                          NaN      35
#
#                                                 Review  \
# 0    Epiduo Forte (adapalene / benzoyl peroxide):\t...
# 1    Epiduo (adapalene / benzoyl peroxide):\t\t\t“T...
# 2    Epiduo Forte (adapalene / benzoyl peroxide):\t...
# 3    “My skin is dry usually, can be very sensitive...
# 4    Epiduo (adapalene / benzoyl peroxide):\t\t\t“I...
# ..                                                 ...
# 852  Epiduo (adapalene / benzoyl peroxide):\t\t\t“I...
# 853  Epiduo (adapalene / benzoyl peroxide):\t\t\t“I...
# 854  Epiduo (adapalene / benzoyl peroxide):\t\t\t“I...
# 855  Epiduo (adapalene / benzoyl peroxide):\t\t\t“I...
# 856  Epiduo (adapalene / benzoyl peroxide):\t\t\t“I...
#
#                              Drug Condition  Major Interaction  \
# 0    Adapalene / benzoyl peroxide      Acne                  1
# 1    Adapalene / benzoyl peroxide      Acne                  1
# 2    Adapalene / benzoyl peroxide      Acne                  1
# 3    Adapalene / benzoyl peroxide      Acne                  1
# 4    Adapalene / benzoyl peroxide      Acne                  1
# ..                            ...       ...                ...
# 852  Adapalene / benzoyl peroxide      Acne                  1
# 853  Adapalene / benzoyl peroxide      Acne                  1
# 854  Adapalene / benzoyl peroxide      Acne                  1
# 855  Adapalene / benzoyl peroxide      Acne                  1
# 856  Adapalene / benzoyl peroxide      Acne                  1
#
#      Moderate Interaction  Minor Interaction       Dosage
# 0                      12                  1  topical gel
# 1                      12                  1  topical gel
# 2                      12                  1  topical gel
# 3                      12                  1  topical gel
# 4                      12                  1  topical gel
# ..                    ...                ...          ...
# 852                    12                  1  topical gel
# 853                    12                  1  topical gel
# 854                    12                  1  topical gel
# 855                    12                  1  topical gel
# 856                    12                  1  topical gel
#
# [832 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/doxycycline/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:22<00:00,  2.11s/it]

# %%
df2 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df2['Drug'] = 'Doxycycline'
df2['Condition'] = 'Acne'
df2['Major Interaction'] = 13
df2['Moderate Interaction'] = 146
df2['Minor Interaction'] = 30
df2['Dosage'] = 'oral'
df2.drop_duplicates(inplace=True)
df2
# Out:
#     Rating                Date                         Taken Helpful  \
# 0      NaN    October 13, 2020  Taken for 6 months to 1 year       2
# 1        7     October 2, 2020                           NaN      32
# 2        8  September 23, 2020       Taken for 1 to 6 months      18
# 3        8  September 22, 2020       Taken for 1 to 6 months       9
# 4      NaN   September 3, 2020                           NaN      15
# ..     ...                 ...                           ...     ...
# 753     10       July 30, 2008                           NaN      25
# 754     10       June 11, 2008                           NaN      44
# 755      9      March 28, 2008                           NaN      11
# 756      9      March 24, 2008                           NaN      13
# 757    NaN      March 20, 2008                           NaN     109
#
#                                                 Review         Drug Condition  \
# 0    “I've been on Doxycycline monohydrate 50mg for...  Doxycycline      Acne
# 1    “I have been taking doxycycline for about a mo...  Doxycycline      Acne
# 2    “Been on this medication doxycycline for almos...  Doxycycline      Acne
# 3    “My dermatologist prescribed me 3 months of do...  Doxycycline      Acne
# 4    “I am doctor and took doxycycline 100mg for ac...  Doxycycline      Acne
# ..                                                 ...          ...       ...
# 753        “Clear for the first time in adult history”  Doxycycline      Acne
# 754  Adoxa (doxycycline):\t\t\t“This medicene worke...  Doxycycline      Acne
# 755  “I have been on this drug for 2 months to help...  Doxycycline      Acne
# 756  “I was prescribed this by my regular doctor fo...  Doxycycline      Acne
# 757  Doryx (doxycycline):\t\t\t“Doryx was originall...  Doxycycline      Acne
#
#      Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                   13                   146                 30   oral
# 1                   13                   146                 30   oral
# 2                   13                   146                 30   oral
# 3                   13                   146                 30   oral
# 4                   13                   146                 30   oral
# ..                 ...                   ...                ...    ...
# 753                 13                   146                 30   oral
# 754                 13                   146                 30   oral
# 755                 13                   146                 30   oral
# 756                 13                   146                 30   oral
# 757                 13                   146                 30   oral
#
# [733 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/adapalene-benzoyl-peroxide-topical/epiduo-for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:05<00:00,  1.67s/it]

# %%
df3 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df3['Drug'] = 'Epiduo'
df3['Condition'] = 'Acne'
df3['Major Interaction'] = 1
df3['Moderate Interaction'] = 12
df3['Minor Interaction'] = 1
df3['Dosage'] = 'topical gel'
df3.drop_duplicates(inplace=True)
df3
# Out:
#     Rating                Date                        Taken Helpful  \
# 0       10    October 25, 2020                          NaN       2
# 1        1  September 30, 2020  Taken for less than 1 month       4
# 2        2  September 18, 2020       Taken for 1 to 2 years       4
# 3        8     August 26, 2020                          NaN      19
# 4       10     August 22, 2020  Taken for less than 1 month      13
# ..     ...                 ...                          ...     ...
# 667      1     January 2, 2010                          NaN      18
# 668    NaN   November 27, 2009                          NaN      45
# 669      2   November 20, 2009                          NaN      17
# 670      9  September 27, 2009                          NaN      60
# 671      9        July 6, 2009                          NaN      35
#
#                                                 Review    Drug Condition  \
# 0    “The very first week of using it I felt like m...  Epiduo      Acne
# 1    “I have been using this product for a few days...  Epiduo      Acne
# 2    “I have been using Epiduo for exactly a year f...  Epiduo      Acne
# 3    “I’ve been using Epiduo since January 24th, 20...  Epiduo      Acne
# 4    “A dermatologist prescribed this for my tween ...  Epiduo      Acne
# ..                                                 ...     ...       ...
# 667  “I am in the first week of using it and I have...  Epiduo      Acne
# 668  “I've been using Epiduo for two months. My doc...  Epiduo      Acne
# 669  “I had an unpleasant experience. I had only us...  Epiduo      Acne
# 670  “I started using this medicine about a week ag...  Epiduo      Acne
# 671  “It seems to be helping a lot. First 2 weeks t...  Epiduo      Acne
#
#      Major Interaction  Moderate Interaction  Minor Interaction       Dosage
# 0                    1                    12                  1  topical gel
# 1                    1                    12                  1  topical gel
# 2                    1                    12                  1  topical gel
# 3                    1                    12                  1  topical gel
# 4                    1                    12                  1  topical gel
# ..                 ...                   ...                ...          ...
# 667                  1                    12                  1  topical gel
# 668                  1                    12                  1  topical gel
# 669                  1                    12                  1  topical gel
# 670                  1                    12                  1  topical gel
# 671                  1                    12                  1  topical gel
#
# [647 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/benzoyl-peroxide-clindamycin-topical/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:03<00:00,  1.62s/it]

# %%
df4 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df4['Drug'] = 'Benzoyl peroxide/clindamycin'
df4['Condition'] = 'Acne'
df4['Major Interaction'] = 17
df4['Moderate Interaction'] = 0
df4['Minor Interaction'] = 1
df4['Dosage'] = 'topical gel'
df4.drop_duplicates(inplace=True)
df4
# Out:
#     Rating                Date                        Taken Helpful  \
# 0       10     August 26, 2020      Taken for 1 to 6 months       3
# 1        1      August 3, 2020  Taken for less than 1 month       5
# 2        7       July 27, 2020   Taken for 10 years or more       6
# 3       10       June 30, 2020      Taken for 1 to 6 months       6
# 4       10        June 7, 2020                          NaN       6
# ..     ...                 ...                          ...     ...
# 558    NaN    February 6, 2009                          NaN      21
# 559    NaN    February 3, 2009                          NaN       8
# 560      6    February 2, 2009                          NaN       4
# 561      9  September 14, 2008                          NaN      30
# 562      9      March 27, 2008                          NaN      33
#
#                                                 Review  \
# 0    Duac (benzoyl peroxide / clindamycin):\t\t\t“I...
# 1    Duac (benzoyl peroxide / clindamycin):\t\t\t“G...
# 2    Benzaclin (benzoyl peroxide / clindamycin):\t\...
# 3    Onexton (benzoyl peroxide / clindamycin):\t\t\...
# 4    Duac (benzoyl peroxide / clindamycin):\t\t\t“I...
# ..                                                 ...
# 558  Duac (benzoyl peroxide / clindamycin):\t\t\t“I...
# 559  Duac (benzoyl peroxide / clindamycin):\t\t\t“I...
# 560  Duac (benzoyl peroxide / clindamycin):\t\t\t“T...
# 561  Benzaclin (benzoyl peroxide / clindamycin):\t\...
# 562  Benzaclin (benzoyl peroxide / clindamycin):\t\...
#
#                              Drug Condition  Major Interaction  \
# 0    Benzoyl peroxide/clindamycin      Acne                 17
# 1    Benzoyl peroxide/clindamycin      Acne                 17
# 2    Benzoyl peroxide/clindamycin      Acne                 17
# 3    Benzoyl peroxide/clindamycin      Acne                 17
# 4    Benzoyl peroxide/clindamycin      Acne                 17
# ..                            ...       ...                ...
# 558  Benzoyl peroxide/clindamycin      Acne                 17
# 559  Benzoyl peroxide/clindamycin      Acne                 17
# 560  Benzoyl peroxide/clindamycin      Acne                 17
# 561  Benzoyl peroxide/clindamycin      Acne                 17
# 562  Benzoyl peroxide/clindamycin      Acne                 17
#
#      Moderate Interaction  Minor Interaction       Dosage
# 0                       0                  1  topical gel
# 1                       0                  1  topical gel
# 2                       0                  1  topical gel
# 3                       0                  1  topical gel
# 4                       0                  1  topical gel
# ..                    ...                ...          ...
# 558                     0                  1  topical gel
# 559                     0                  1  topical gel
# 560                     0                  1  topical gel
# 561                     0                  1  topical gel
# 562                     0                  1  topical gel
#
# [538 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/drospirenone-ethinyl-estradiol/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:05<00:00,  1.69s/it]

# %%
df5 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df5['Drug'] = 'Drospirenone/ethinyl estradiol'
df5['Condition'] = 'Acne'
df5['Major Interaction'] = 53
df5['Moderate Interaction'] = 377
df5['Minor Interaction'] = 42
df5['Dosage'] = 'oral'
df5.drop_duplicates(inplace=True)
df5
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        7     October 3, 2020                          NaN       4
# 1        1  September 11, 2020  Taken for less than 1 month       0
# 2        4   September 6, 2020  Taken for less than 1 month       6
# 3        8   September 5, 2020      Taken for 1 to 6 months      11
# 4        8   September 1, 2020  Taken for less than 1 month       3
# ..     ...                 ...                          ...     ...
# 547    NaN   December 15, 2008                          NaN      13
# 548     10       June 28, 2008                          NaN      96
# 549     10       June 24, 2008                          NaN      42
# 550      9      April 23, 2008                          NaN      83
# 551     10       April 2, 2008                          NaN      49
#
#                                                 Review  \
# 0    Yaz (drospirenone / ethinyl estradiol):\t\t\t“...
# 1    Nikki (drospirenone / ethinyl estradiol):\t\t\...
# 2    Yaz (drospirenone / ethinyl estradiol):\t\t\t“...
# 3    Yaz (drospirenone / ethinyl estradiol):\t\t\t“...
# 4    Nikki (drospirenone / ethinyl estradiol):\t\t\...
# ..                                                 ...
# 547  Yasmin (drospirenone / ethinyl estradiol):\t\t...
# 548  Yaz (drospirenone / ethinyl estradiol):\t\t\t“...
# 549  Yasmin (drospirenone / ethinyl estradiol):\t\t...
# 550  Yaz (drospirenone / ethinyl estradiol):\t\t\t“...
# 551  Yasmin (drospirenone / ethinyl estradiol):\t\t...
#
#                                Drug Condition  Major Interaction  \
# 0    Drospirenone/ethinyl estradiol      Acne                 53
# 1    Drospirenone/ethinyl estradiol      Acne                 53
# 2    Drospirenone/ethinyl estradiol      Acne                 53
# 3    Drospirenone/ethinyl estradiol      Acne                 53
# 4    Drospirenone/ethinyl estradiol      Acne                 53
# ..                              ...       ...                ...
# 547  Drospirenone/ethinyl estradiol      Acne                 53
# 548  Drospirenone/ethinyl estradiol      Acne                 53
# 549  Drospirenone/ethinyl estradiol      Acne                 53
# 550  Drospirenone/ethinyl estradiol      Acne                 53
# 551  Drospirenone/ethinyl estradiol      Acne                 53
#
#      Moderate Interaction  Minor Interaction Dosage
# 0                     377                 42   oral
# 1                     377                 42   oral
# 2                     377                 42   oral
# 3                     377                 42   oral
# 4                     377                 42   oral
# ..                    ...                ...    ...
# 547                   377                 42   oral
# 548                   377                 42   oral
# 549                   377                 42   oral
# 550                   377                 42   oral
# 551                   377                 42   oral
#
# [526 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/minocycline/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:06<00:00,  1.71s/it]

# %%
df6 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df6['Drug'] = 'Minocycline'
df6['Condition'] = 'Acne'
df6['Major Interaction'] = 15
df6['Moderate Interaction'] = 146
df6['Minor Interaction'] = 26
df6['Dosage'] = 'oral'
df6.drop_duplicates(inplace=True)
df6
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        3   September 5, 2020                          NaN       8
# 1        6     August 26, 2020  Taken for less than 1 month       3
# 2        1     August 21, 2020  Taken for less than 1 month       3
# 3        1       June 18, 2020  Taken for less than 1 month      15
# 4        9        May 12, 2020      Taken for 1 to 6 months      12
# ..     ...                 ...                          ...     ...
# 478      9   November 12, 2008                          NaN       5
# 479    NaN    November 3, 2008                          NaN      48
# 480      9    October 30, 2008                          NaN       6
# 481      9  September 13, 2008                          NaN      59
# 482      9       July 24, 2008                          NaN      31
#
#                                                 Review         Drug Condition  \
# 0    “After one week or two, I was taking 2 minocyc...  Minocycline      Acne
# 1    “I have been taking 100mg Minocycline 2x a day...  Minocycline      Acne
# 2    “I had a horrible experience on this minocycli...  Minocycline      Acne
# 3    “Minocycline made me super sick. I thought I h...  Minocycline      Acne
# 4    Minocin (minocycline):\t\t\t“Minocycline worke...  Minocycline      Acne
# ..                                                 ...          ...       ...
# 478  “I use this medication whenever I have a flare...  Minocycline      Acne
# 479  Minocin (minocycline):\t\t\t“I used this medic...  Minocycline      Acne
# 480  “I had a severe case of acne mechanica from a ...  Minocycline      Acne
# 481  “I had mild-sometimes moderate acne vulgaris. ...  Minocycline      Acne
# 482  “Minocycline, used in combination with a topic...  Minocycline      Acne
#
#      Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                   15                   146                 26   oral
# 1                   15                   146                 26   oral
# 2                   15                   146                 26   oral
# 3                   15                   146                 26   oral
# 4                   15                   146                 26   oral
# ..                 ...                   ...                ...    ...
# 478                 15                   146                 26   oral
# 479                 15                   146                 26   oral
# 480                 15                   146                 26   oral
# 481                 15                   146                 26   oral
# 482                 15                   146                 26   oral
#
# [458 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/ethinyl-estradiol-norgestimate/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:05<00:00,  1.68s/it]

# %%
df7 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df7['Drug'] = 'Ethinyl estradiol/norgestimate'
df7['Condition'] = 'Acne'
df7['Major Interaction'] = 34
df7['Moderate Interaction'] = 329
df7['Minor Interaction'] = 45
df7['Dosage'] = 'oral'
df7.drop_duplicates(inplace=True)
df7
# Out:
#     Rating               Date                         Taken Helpful  \
# 0        5   October 22, 2020   Taken for less than 1 month       1
# 1       10   October 11, 2020                           NaN       2
# 2        1    August 31, 2020   Taken for less than 1 month       1
# 3        4    August 30, 2020       Taken for 1 to 6 months       4
# 4        7    August 27, 2020  Taken for 6 months to 1 year       1
# ..     ...                ...                           ...     ...
# 474      9      June 19, 2011                           NaN       9
# 475     10       June 7, 2011                           NaN      33
# 476      8     March 18, 2011                           NaN       9
# 477      9  December 22, 2010                           NaN      43
# 478    NaN   October 17, 2010                           NaN      17
#
#                                                 Review  \
# 0    Estarylla (ethinyl estradiol / norgestimate):\...
# 1    Tri-Linyah (ethinyl estradiol / norgestimate):...
# 2    Tri-Lo-Marzia (ethinyl estradiol / norgestimat...
# 3    Estarylla (ethinyl estradiol / norgestimate):\...
# 4    Tri-Sprintec (ethinyl estradiol / norgestimate...
# ..                                                 ...
# 474  TriNessa (ethinyl estradiol / norgestimate):\t...
# 475  TriNessa (ethinyl estradiol / norgestimate):\t...
# 476  TriNessa (ethinyl estradiol / norgestimate):\t...
# 477  TriNessa (ethinyl estradiol / norgestimate):\t...
# 478  Tri-Sprintec (ethinyl estradiol / norgestimate...
#
#                                Drug Condition  Major Interaction  \
# 0    Ethinyl estradiol/norgestimate      Acne                 34
# 1    Ethinyl estradiol/norgestimate      Acne                 34
# 2    Ethinyl estradiol/norgestimate      Acne                 34
# 3    Ethinyl estradiol/norgestimate      Acne                 34
# 4    Ethinyl estradiol/norgestimate      Acne                 34
# ..                              ...       ...                ...
# 474  Ethinyl estradiol/norgestimate      Acne                 34
# 475  Ethinyl estradiol/norgestimate      Acne                 34
# 476  Ethinyl estradiol/norgestimate      Acne                 34
# 477  Ethinyl estradiol/norgestimate      Acne                 34
# 478  Ethinyl estradiol/norgestimate      Acne                 34
#
#      Moderate Interaction  Minor Interaction Dosage
# 0                     329                 45   oral
# 1                     329                 45   oral
# 2                     329                 45   oral
# 3                     329                 45   oral
# 4                     329                 45   oral
# ..                    ...                ...    ...
# 474                   329                 45   oral
# 475                   329                 45   oral
# 476                   329                 45   oral
# 477                   329                 45   oral
# 478                   329                 45   oral
#
# [454 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/adapalene-topical/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:01<00:00,  1.58s/it]

# %%
df8 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df8['Drug'] = 'Ethinyl estradiol/norgestimate'
df8['Condition'] = 'Acne'
df8['Major Interaction'] = 1
df8['Moderate Interaction'] = 10
df8['Minor Interaction'] = 0
df8['Dosage'] = 'topical gel'
df8.drop_duplicates(inplace=True)
df8
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        1     October 6, 2020      Taken for 1 to 6 months       7
# 1        8  September 16, 2020                          NaN       8
# 2        9   September 3, 2020                          NaN      23
# 3        2   September 2, 2020  Taken for less than 1 month       4
# 4        2     August 30, 2020      Taken for 1 to 6 months      10
# ..     ...                 ...                          ...     ...
# 469      7       July 10, 2009                          NaN      29
# 470      7      March 19, 2009                          NaN      22
# 471     10   December 30, 2008                          NaN      29
# 472      9   December 19, 2008                          NaN      47
# 473      8    December 7, 2008                          NaN      45
#
#                                                 Review  \
# 0    Differin (adapalene):\t\t\t“HORRIBLE!!!!!\r\nM...
# 1    Differin (adapalene):\t\t\t“I recommend you to...
# 2    Differin (adapalene):\t\t\t“I started Differin...
# 3    Differin (adapalene):\t\t\t“After suffering wi...
# 4    Differin (adapalene):\t\t\t“I am on month 4 an...
# ..                                                 ...
# 469  Differin (adapalene):\t\t\t“I've been using Di...
# 470  Differin (adapalene):\t\t\t“I love Differin. M...
# 471  Differin (adapalene):\t\t\t“I don't have that ...
# 472  Differin (adapalene):\t\t\t“My acne became wor...
# 473  Differin (adapalene):\t\t\t“This medication he...
#
#                                Drug Condition  Major Interaction  \
# 0    Ethinyl estradiol/norgestimate      Acne                  1
# 1    Ethinyl estradiol/norgestimate      Acne                  1
# 2    Ethinyl estradiol/norgestimate      Acne                  1
# 3    Ethinyl estradiol/norgestimate      Acne                  1
# 4    Ethinyl estradiol/norgestimate      Acne                  1
# ..                              ...       ...                ...
# 469  Ethinyl estradiol/norgestimate      Acne                  1
# 470  Ethinyl estradiol/norgestimate      Acne                  1
# 471  Ethinyl estradiol/norgestimate      Acne                  1
# 472  Ethinyl estradiol/norgestimate      Acne                  1
# 473  Ethinyl estradiol/norgestimate      Acne                  1
#
#      Moderate Interaction  Minor Interaction       Dosage
# 0                      10                  0  topical gel
# 1                      10                  0  topical gel
# 2                      10                  0  topical gel
# 3                      10                  0  topical gel
# 4                      10                  0  topical gel
# ..                    ...                ...          ...
# 469                    10                  0  topical gel
# 470                    10                  0  topical gel
# 471                    10                  0  topical gel
# 472                    10                  0  topical gel
# 473                    10                  0  topical gel
#
# [449 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/tretinoin-topical/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:01<00:00,  1.57s/it]

# %%
df9 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df9['Drug'] = 'Ethinyl estradiol/norgestimate'
df9['Condition'] = 'Acne'
df9['Major Interaction'] = 1
df9['Moderate Interaction'] = 10
df9['Minor Interaction'] = 0
df9['Dosage'] = 'topical gel'
df9.drop_duplicates(inplace=True)
df9
# Out:
#     Rating              Date                        Taken Helpful  \
# 0       10   October 5, 2020      Taken for 1 to 6 months       1
# 1        1   August 24, 2020  Taken for less than 1 month       5
# 2       10   August 21, 2020      Taken for 1 to 6 months      19
# 3       10    August 1, 2020                          NaN      13
# 4        2     June 29, 2020                          NaN      17
# ..     ...               ...                          ...     ...
# 437      1     June 15, 2009                          NaN       3
# 438     10      May 17, 2009                          NaN      78
# 439     10      May 16, 2009                          NaN       4
# 440      8  October 31, 2008                          NaN      68
# 441      8    August 4, 2008                          NaN     101
#
#                                                 Review  \
# 0    Retin-A (tretinoin):\t\t\t“I have been on this...
# 1    Stieva-A (tretinoin):\t\t\t“This cream is abso...
# 2    Retin-A (tretinoin):\t\t\t“33 yo/female. Had a...
# 3    Retin-A (tretinoin):\t\t\t“Retin A..wow is all...
# 4    “I applied it at night and 2 weeks only gets w...
# ..                                                 ...
# 437  Tretin-X (tretinoin):\t\t\t“My daughter used T...
# 438  Atralin (tretinoin):\t\t\t“Never had acne but ...
# 439                               “Amazingly helpful.”
# 440  Retin A Micro (tretinoin):\t\t\t“This medicati...
# 441  Atralin (tretinoin):\t\t\t“My skin is very sen...
#
#                                Drug Condition  Major Interaction  \
# 0    Ethinyl estradiol/norgestimate      Acne                  1
# 1    Ethinyl estradiol/norgestimate      Acne                  1
# 2    Ethinyl estradiol/norgestimate      Acne                  1
# 3    Ethinyl estradiol/norgestimate      Acne                  1
# 4    Ethinyl estradiol/norgestimate      Acne                  1
# ..                              ...       ...                ...
# 437  Ethinyl estradiol/norgestimate      Acne                  1
# 438  Ethinyl estradiol/norgestimate      Acne                  1
# 439  Ethinyl estradiol/norgestimate      Acne                  1
# 440  Ethinyl estradiol/norgestimate      Acne                  1
# 441  Ethinyl estradiol/norgestimate      Acne                  1
#
#      Moderate Interaction  Minor Interaction       Dosage
# 0                      10                  0  topical gel
# 1                      10                  0  topical gel
# 2                      10                  0  topical gel
# 3                      10                  0  topical gel
# 4                      10                  0  topical gel
# ..                    ...                ...          ...
# 437                    10                  0  topical gel
# 438                    10                  0  topical gel
# 439                    10                  0  topical gel
# 440                    10                  0  topical gel
# 441                    10                  0  topical gel
#
# [417 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/spironolactone/for-acne.html?page={}"
max_results_per_page = 39
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 39/39 [01:03<00:00,  1.64s/it]

# %%
df10 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df10['Drug'] = 'Ethinyl estradiol/norgestimate'
df10['Condition'] = 'Acne'
df10['Major Interaction'] = 44
df10['Moderate Interaction'] = 277
df10['Minor Interaction'] = 23
df10['Dosage'] = 'oral'
df10.drop_duplicates(inplace=True)
df10
# Out:
#     Rating                Date                         Taken Helpful  \
# 0        8    November 3, 2020        Taken for 2 to 5 years       2
# 1       10  September 18, 2020  Taken for 6 months to 1 year      11
# 2        1   September 6, 2020                           NaN       6
# 3       10   September 5, 2020                           NaN       7
# 4       10   September 4, 2020  Taken for 6 months to 1 year       8
# ..     ...                 ...                           ...     ...
# 392      8      April 17, 2009                           NaN      23
# 393      8    October 30, 2008                           NaN      12
# 394      8        July 2, 2008                           NaN      36
# 395     10       June 19, 2008                           NaN      31
# 396     10      March 10, 2008                           NaN      50
#
#                                                 Review  \
# 0    “I was on spiro for several years. It helped b...
# 1    “I was put on Spiro for acne. My face was the ...
# 2    “It’s my 5th day on this medicine (spironolact...
# 3    “I was on spirolactone when I was about 14, an...
# 4    “This medication spironolactone is amazing for...
# ..                                                 ...
# 392  “I was prescribed this from my dermatologist f...
# 393              “It worked over a period of 24 hours”
# 394  “I was diagnosed with polycystic ovaries a cou...
# 395  “I always used used to get pimples before. Now...
# 396  “I was suffering from acne and this has cured ...
#
#                                Drug Condition  Major Interaction  \
# 0    Ethinyl estradiol/norgestimate      Acne                 44
# 1    Ethinyl estradiol/norgestimate      Acne                 44
# 2    Ethinyl estradiol/norgestimate      Acne                 44
# 3    Ethinyl estradiol/norgestimate      Acne                 44
# 4    Ethinyl estradiol/norgestimate      Acne                 44
# ..                              ...       ...                ...
# 392  Ethinyl estradiol/norgestimate      Acne                 44
# 393  Ethinyl estradiol/norgestimate      Acne                 44
# 394  Ethinyl estradiol/norgestimate      Acne                 44
# 395  Ethinyl estradiol/norgestimate      Acne                 44
# 396  Ethinyl estradiol/norgestimate      Acne                 44
#
#      Moderate Interaction  Minor Interaction Dosage
# 0                     277                 23   oral
# 1                     277                 23   oral
# 2                     277                 23   oral
# 3                     277                 23   oral
# 4                     277                 23   oral
# ..                    ...                ...    ...
# 392                   277                 23   oral
# 393                   277                 23   oral
# 394                   277                 23   oral
# 395                   277                 23   oral
# 396                   277                 23   oral
#
# [372 rows x 11 columns]

# %%
frames = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
df_acne = pd.concat(frames)

# %%
df_acne.reset_index(inplace=True, drop=True)

# %%
df_acne
# Out:
#      Rating                Date                         Taken Helpful  \
# 0         1  September 18, 2020       Taken for 1 to 6 months      19
# 1        10   September 5, 2020                           NaN       6
# 2         2     August 25, 2020  Taken for 6 months to 1 year       9
# 3        10     August 22, 2020  Taken for 6 months to 1 year       9
# 4         3     August 22, 2020       Taken for 1 to 6 months       9
# ...     ...                 ...                           ...     ...
# 6354      8      April 17, 2009                           NaN      23
# 6355      8    October 30, 2008                           NaN      12
# 6356      8        July 2, 2008                           NaN      36
# 6357     10       June 19, 2008                           NaN      31
# 6358     10      March 10, 2008                           NaN      50
#
#                                                  Review  \
# 0     Accutane (isotretinoin):\t\t\t“I TOOK THIS POI...
# 1     Myorisan (isotretinoin):\t\t\t“This is my sixt...
# 2     Accutane (isotretinoin):\t\t\t“There is no dou...
# 3     Claravis (isotretinoin):\t\t\t“A month after f...
# 4     Accutane (isotretinoin):\t\t\t“I took this hor...
# ...                                                 ...
# 6354  “I was prescribed this from my dermatologist f...
# 6355              “It worked over a period of 24 hours”
# 6356  “I was diagnosed with polycystic ovaries a cou...
# 6357  “I always used used to get pimples before. Now...
# 6358  “I was suffering from acne and this has cured ...
#
#                                 Drug Condition  Major Interaction  \
# 0                       isotretinoin      Acne                 19
# 1                       isotretinoin      Acne                 19
# 2                       isotretinoin      Acne                 19
# 3                       isotretinoin      Acne                 19
# 4                       isotretinoin      Acne                 19
# ...                              ...       ...                ...
# 6354  Ethinyl estradiol/norgestimate      Acne                 44
# 6355  Ethinyl estradiol/norgestimate      Acne                 44
# 6356  Ethinyl estradiol/norgestimate      Acne                 44
# 6357  Ethinyl estradiol/norgestimate      Acne                 44
# 6358  Ethinyl estradiol/norgestimate      Acne                 44
#
#       Moderate Interaction  Minor Interaction Dosage
# 0                       82                  0   oral
# 1                       82                  0   oral
# 2                       82                  0   oral
# 3                       82                  0   oral
# 4                       82                  0   oral
# ...                    ...                ...    ...
# 6354                   277                 23   oral
# 6355                   277                 23   oral
# 6356                   277                 23   oral
# 6357                   277                 23   oral
# 6358                   277                 23   oral
#
# [6359 rows x 11 columns]

# %%
#save to CSV as master 
df_acne.to_csv("df_acne.csv")
