# %%
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm import tqdm
from time import time, sleep

# %%
url_template = "https://www.drugs.com/comments/atorvastatin/for-hyperlipidemia.html?page={}"
max_results_per_page = 9
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 9/9 [00:16<00:00,  1.80s/it]

# %%
df = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df['Drug'] = 'Atorvastatin'
df['Condition'] = 'Cholesterol'
df['Major Interaction'] = 41
df['Moderate Interaction'] = 235
df['Minor Interaction'] = 33
df['Dosage'] = 'oral'
df.drop_duplicates(inplace=True)
df
# Out:
#     Rating                Date                    Taken Helpful  \
# 0        6      August 7, 2020                      NaN      12
# 1       10       June 16, 2020   Taken for 2 to 5 years      20
# 2        1        June 6, 2020  Taken for 1 to 6 months      61
# 3        1        June 5, 2020  Taken for 1 to 6 months      46
# 4        1        June 2, 2020                      NaN      21
# ..     ...                 ...                      ...     ...
# 205      5   February 28, 2009                      NaN      91
# 206      3   February 17, 2009                      NaN     169
# 207      8  September 30, 2008                      NaN      28
# 208      9       July 28, 2008                      NaN      80
# 209     10       June 10, 2008                      NaN      69
#
#                                                 Review          Drug  \
# 0    “Before starting taking atorvastatin 10mg: 230...  Atorvastatin
# 1    “Been taking this drug for 4 yrs now after exp...  Atorvastatin
# 2    Lipitor (atorvastatin):\t\t\t“So I went to the...  Atorvastatin
# 3    Lipitor (atorvastatin):\t\t\t“After taking Lip...  Atorvastatin
# 4    “I am so happy to see that it’s just not me ha...  Atorvastatin
# ..                                                 ...           ...
# 205  Lipitor (atorvastatin):\t\t\t“Lowers cholestor...  Atorvastatin
# 206  Lipitor (atorvastatin):\t\t\t“Many side effect...  Atorvastatin
# 207  Lipitor (atorvastatin):\t\t\t“Works best for m...  Atorvastatin
# 208  Lipitor (atorvastatin):\t\t\t“This medicine is...  Atorvastatin
# 209    Lipitor (atorvastatin):\t\t\t“Works very well.”  Atorvastatin
#
#        Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Cholesterol                 41                   235                 33
# 1    Cholesterol                 41                   235                 33
# 2    Cholesterol                 41                   235                 33
# 3    Cholesterol                 41                   235                 33
# 4    Cholesterol                 41                   235                 33
# ..           ...                ...                   ...                ...
# 205  Cholesterol                 41                   235                 33
# 206  Cholesterol                 41                   235                 33
# 207  Cholesterol                 41                   235                 33
# 208  Cholesterol                 41                   235                 33
# 209  Cholesterol                 41                   235                 33
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 205   oral
# 206   oral
# 207   oral
# 208   oral
# 209   oral
#
# [185 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/evolocumab/for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:19<00:00,  1.65s/it]

# %%
df1 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df1['Drug'] = 'Evolocumab'
df1['Condition'] = 'Cholesterol'
df1['Major Interaction'] = 0
df1['Moderate Interaction'] = 0
df1['Minor Interaction'] = 0
df1['Dosage'] = 'injection'
df1.drop_duplicates(inplace=True)
df1
# Out:
#     Rating               Date                    Taken Helpful  \
# 0        1   October 18, 2020                      NaN       6
# 1        5    October 4, 2020  Taken for 1 to 6 months       9
# 2        1  September 4, 2020  Taken for 1 to 6 months      34
# 3        1    August 25, 2020  Taken for 1 to 6 months      29
# 4        3    August 21, 2020  Taken for 1 to 6 months      24
# ..     ...                ...                      ...     ...
# 234      2      June 13, 2016  Taken for 1 to 6 months      54
# 235     10       June 7, 2016                      NaN      29
# 236     10       June 3, 2016  Taken for 1 to 6 months      22
# 237      1     April 29, 2016  Taken for 1 to 6 months      49
# 238      1     April 29, 2016                      NaN      34
#
#                                                 Review        Drug  \
# 0    Repatha (evolocumab):\t\t\t“The Repatha slowly...  Evolocumab
# 1    Repatha (evolocumab):\t\t\t“I've been on many ...  Evolocumab
# 2    Repatha (evolocumab):\t\t\t“I’ve taken 7 doses...  Evolocumab
# 3    Repatha (evolocumab):\t\t\t“I have previously ...  Evolocumab
# 4    Repatha (evolocumab):\t\t\t“Started Repatha be...  Evolocumab
# ..                                                 ...         ...
# 234  Repatha (evolocumab):\t\t\t“I have muscle ache...  Evolocumab
# 235  Repatha (evolocumab):\t\t\t“Fantastic miracle ...  Evolocumab
# 236  Repatha (evolocumab):\t\t\t“3 months on drug. ...  Evolocumab
# 237  Repatha (evolocumab):\t\t\t“I had a heart atta...  Evolocumab
# 238  Repatha (evolocumab):\t\t\t“I had a heart atta...  Evolocumab
#
#        Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Cholesterol                  0                     0                  0
# 1    Cholesterol                  0                     0                  0
# 2    Cholesterol                  0                     0                  0
# 3    Cholesterol                  0                     0                  0
# 4    Cholesterol                  0                     0                  0
# ..           ...                ...                   ...                ...
# 234  Cholesterol                  0                     0                  0
# 235  Cholesterol                  0                     0                  0
# 236  Cholesterol                  0                     0                  0
# 237  Cholesterol                  0                     0                  0
# 238  Cholesterol                  0                     0                  0
#
#         Dosage
# 0    injection
# 1    injection
# 2    injection
# 3    injection
# 4    injection
# ..         ...
# 234  injection
# 235  injection
# 236  injection
# 237  injection
# 238  injection
#
# [214 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/evolocumab/repatha-for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:20<00:00,  1.70s/it]

# %%
df2 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df2['Drug'] = 'Repatha'
df2['Condition'] = 'Cholesterol'
df2['Major Interaction'] = 0
df2['Moderate Interaction'] = 0
df2['Minor Interaction'] = 0
df2['Dosage'] = 'injection'
df2.drop_duplicates(inplace=True)
df2
# Out:
#     Rating               Date                    Taken Helpful  \
# 0        1   October 18, 2020                      NaN       6
# 1        5    October 4, 2020  Taken for 1 to 6 months       9
# 2        1  September 4, 2020  Taken for 1 to 6 months      34
# 3        1    August 25, 2020  Taken for 1 to 6 months      29
# 4        3    August 21, 2020  Taken for 1 to 6 months      24
# ..     ...                ...                      ...     ...
# 231      2      June 13, 2016  Taken for 1 to 6 months      54
# 232     10       June 7, 2016                      NaN      29
# 233     10       June 3, 2016  Taken for 1 to 6 months      22
# 234      1     April 29, 2016  Taken for 1 to 6 months      49
# 235      1     April 29, 2016                      NaN      34
#
#                                                 Review     Drug    Condition  \
# 0    “The Repatha slowly is making me worse.\nMy he...  Repatha  Cholesterol
# 1    “I've been on many statins  and after taking t...  Repatha  Cholesterol
# 2    “I’ve taken 7 doses of Repatha. I have been ex...  Repatha  Cholesterol
# 3    “I have previously been unable to take any cho...  Repatha  Cholesterol
# 4    “Started Repatha because I am hyper-sensitive ...  Repatha  Cholesterol
# ..                                                 ...      ...          ...
# 231  “I have muscle aches with statins. Tried Repat...  Repatha  Cholesterol
# 232  “Fantastic miracle drug! I'm only 34 but had a...  Repatha  Cholesterol
# 233  “3 months on drug. No noticeable side effects....  Repatha  Cholesterol
# 234  “I had a heart attack and stent and have a pro...  Repatha  Cholesterol
# 235  “I had a heart attack and stent and have a pro...  Repatha  Cholesterol
#
#      Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                    0                     0                  0  injection
# 1                    0                     0                  0  injection
# 2                    0                     0                  0  injection
# 3                    0                     0                  0  injection
# 4                    0                     0                  0  injection
# ..                 ...                   ...                ...        ...
# 231                  0                     0                  0  injection
# 232                  0                     0                  0  injection
# 233                  0                     0                  0  injection
# 234                  0                     0                  0  injection
# 235                  0                     0                  0  injection
#
# [211 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/rosuvastatin/crestor-for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:18<00:00,  1.56s/it]

# %%
df3 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df3['Drug'] = 'Crestor'
df3['Condition'] = 'Cholesterol'
df3['Major Interaction'] = 22
df3['Moderate Interaction'] = 151
df3['Minor Interaction'] = 10
df3['Dosage'] = 'oral'
df3.drop_duplicates(inplace=True)
df3
# Out:
#     Rating                Date                    Taken Helpful  \
# 0        4    November 1, 2020   Taken for 1 to 2 years       0
# 1        1    October 13, 2020   Taken for 1 to 2 years       7
# 2        1        May 28, 2020                      NaN      60
# 3        1        May 11, 2020  Taken for 1 to 6 months      41
# 4        7         May 5, 2020  Taken for 1 to 6 months      42
# ..     ...                 ...                      ...     ...
# 116      9   November 11, 2008                      NaN      80
# 117    NaN    November 1, 2008                      NaN     107
# 118     10  September 23, 2008                      NaN      48
# 119     10       July 28, 2008                      NaN      77
# 120     10       April 2, 2008                      NaN     156
#
#                                                 Review     Drug    Condition  \
# 0    “Hi, been on Crestor for about a year. Cholest...  Crestor  Cholesterol
# 1    “Honestly the drug requires more research to s...  Crestor  Cholesterol
# 2    “I have been on 40mg Rosuvastatin with 10mg ez...  Crestor  Cholesterol
# 3    “Never been on a statin, early 50's, fit / act...  Crestor  Cholesterol
# 4    “I lost my thyroid to cancer and have been exp...  Crestor  Cholesterol
# ..                                                 ...      ...          ...
# 116  “My doctor switched me from Lipitor to Crestor...  Crestor  Cholesterol
# 117  “Experienced just about every side effect. Ear...  Crestor  Cholesterol
# 118  “Crestor did an excellent job for me. I am now...  Crestor  Cholesterol
# 119  “I lowered my cholesterol approximately 100 po...  Crestor  Cholesterol
# 120  “Crestor has been the only statin that has low...  Crestor  Cholesterol
#
#      Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                   22                   151                 10   oral
# 1                   22                   151                 10   oral
# 2                   22                   151                 10   oral
# 3                   22                   151                 10   oral
# 4                   22                   151                 10   oral
# ..                 ...                   ...                ...    ...
# 116                 22                   151                 10   oral
# 117                 22                   151                 10   oral
# 118                 22                   151                 10   oral
# 119                 22                   151                 10   oral
# 120                 22                   151                 10   oral
#
# [96 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/simvastatin/for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:18<00:00,  1.58s/it]

# %%
df4 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df4['Drug'] = 'Simvastatin'
df4['Condition'] = 'Cholesterol'
df4['Major Interaction'] = 52
df4['Moderate Interaction'] = 201
df4['Minor Interaction'] = 10
df4['Dosage'] = 'oral'
df4.drop_duplicates(inplace=True)
df4
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        1     October 6, 2020  Taken for less than 1 month       1
# 1        7  September 22, 2020       Taken for 1 to 2 years       1
# 2        6    January 24, 2020      Taken for 5 to 10 years      10
# 3        1    January 23, 2020                          NaN       3
# 4        9  September 17, 2019      Taken for 1 to 6 months      13
# ..     ...                 ...                          ...     ...
# 123    NaN   November 24, 2008                          NaN      62
# 124      7        July 6, 2008                          NaN      22
# 125     10       June 23, 2008                          NaN      94
# 126     10        May 21, 2008                          NaN      74
# 127    NaN    October 10, 2007                          NaN     290
#
#                                                 Review         Drug  \
# 0    “Took three 10mg simvastatin tablets ...  1st ...  Simvastatin
# 1    “So I was a STEMI and after stent insertion, I...  Simvastatin
# 2    “I was put on this medication in 2011. It lowe...  Simvastatin
# 3           “it gave me big poops at night night time”  Simvastatin
# 4    “Started taking 40mg Simvastatin.  Had zero si...  Simvastatin
# ..                                                 ...          ...
# 123  “I am unfortunately one of those who had a bad...  Simvastatin
# 124  “appears to work satisfactorily. Dr. instructi...  Simvastatin
# 125  Zocor (simvastatin):\t\t\t“Lowered my choleste...  Simvastatin
# 126  Zocor (simvastatin):\t\t\t“Zocor 20mg/daay for...  Simvastatin
# 127  Zocor (simvastatin):\t\t\t“I was prescribed zo...  Simvastatin
#
#        Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Cholesterol                 52                   201                 10
# 1    Cholesterol                 52                   201                 10
# 2    Cholesterol                 52                   201                 10
# 3    Cholesterol                 52                   201                 10
# 4    Cholesterol                 52                   201                 10
# ..           ...                ...                   ...                ...
# 123  Cholesterol                 52                   201                 10
# 124  Cholesterol                 52                   201                 10
# 125  Cholesterol                 52                   201                 10
# 126  Cholesterol                 52                   201                 10
# 127  Cholesterol                 52                   201                 10
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 123   oral
# 124   oral
# 125   oral
# 126   oral
# 127   oral
#
# [103 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/ezetimibe/for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:18<00:00,  1.58s/it]

# %%
df5 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df5['Drug'] = 'Ezetimibe'
df5['Condition'] = 'Cholesterol'
df5['Major Interaction'] = 0
df5['Moderate Interaction'] = 30
df5['Minor Interaction'] = 4
df5['Dosage'] = 'oral'
df5.drop_duplicates(inplace=True)
df5
# Out:
#     Rating                Date                        Taken Helpful  \
# 0        1    November 3, 2020                          NaN       0
# 1        5    October 30, 2020      Taken for 1 to 6 months       3
# 2        1    October 18, 2020  Taken for less than 1 month       5
# 3        1     October 5, 2020  Taken for less than 1 month       8
# 4        1  September 17, 2020  Taken for less than 1 month      10
# ..     ...                 ...                          ...     ...
# 113      9   September 2, 2009                          NaN      82
# 114      4     August 12, 2009                          NaN     122
# 115      1       June 17, 2009                          NaN      13
# 116      9    February 8, 2009                          NaN      60
# 117     10      March 31, 2008                          NaN      84
#
#                                                 Review       Drug  \
# 0    “Have been unable to tolerate statins so doc r...  Ezetimibe
# 1    Zetia (ezetimibe):\t\t\t“Started on Zetia on t...  Ezetimibe
# 2    “Had high cholesterol for over 40 years & runs...  Ezetimibe
# 3    “I have decided to stop taking this horrible m...  Ezetimibe
# 4    “I am a 68 yr old female. 4 days ago I started...  Ezetimibe
# ..                                                 ...        ...
# 113  Zetia (ezetimibe):\t\t\t“I have not had any ba...  Ezetimibe
# 114  Zetia (ezetimibe):\t\t\t“I took it for about 2...  Ezetimibe
# 115    “Didn't make any difference to my cholesterol.”  Ezetimibe
# 116  Zetia (ezetimibe):\t\t\t“My medical profession...  Ezetimibe
# 117  Zetia (ezetimibe):\t\t\t“Cut my LDL in half wh...  Ezetimibe
#
#        Condition  Major Interaction  Moderate Interaction  Minor Interaction  \
# 0    Cholesterol                  0                    30                  4
# 1    Cholesterol                  0                    30                  4
# 2    Cholesterol                  0                    30                  4
# 3    Cholesterol                  0                    30                  4
# 4    Cholesterol                  0                    30                  4
# ..           ...                ...                   ...                ...
# 113  Cholesterol                  0                    30                  4
# 114  Cholesterol                  0                    30                  4
# 115  Cholesterol                  0                    30                  4
# 116  Cholesterol                  0                    30                  4
# 117  Cholesterol                  0                    30                  4
#
#     Dosage
# 0     oral
# 1     oral
# 2     oral
# 3     oral
# 4     oral
# ..     ...
# 113   oral
# 114   oral
# 115   oral
# 116   oral
# 117   oral
#
# [93 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/pitavastatin/livalo-for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:17<00:00,  1.49s/it]

# %%
df6 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df6['Drug'] = 'Livalo'
df6['Condition'] = 'Cholesterol'
df6['Major Interaction'] = 15
df6['Moderate Interaction'] = 118
df6['Minor Interaction'] = 3
df6['Dosage'] = 'oral'
df6.drop_duplicates(inplace=True)
df6
# Out:
#     Rating                Date                         Taken Helpful  \
# 0        8  September 12, 2020  Taken for 6 months to 1 year       7
# 1       10       July 22, 2020  Taken for 6 months to 1 year       7
# 2        5   February 28, 2020  Taken for 6 months to 1 year       4
# 3        9   February 23, 2020       Taken for 1 to 6 months       8
# 4        5   December 15, 2019       Taken for 1 to 6 months      15
# ..     ...                 ...                           ...     ...
# 96       9         May 1, 2011                           NaN     121
# 97     NaN    January 30, 2011                           NaN     147
# 98       8    January 27, 2011                           NaN      78
# 99       6    January 24, 2011                           NaN      72
# 100     10   November 21, 2010                           NaN     113
#
#                                                 Review    Drug    Condition  \
# 0    “I have taken Livalo 2 mg for 9+ months.  Rece...  Livalo  Cholesterol
# 1    “Livalo is a great drug, on 2 mg LIVALO for 11...  Livalo  Cholesterol
# 2    “I’ve been on 2mg Livalo for about 6 months. I...  Livalo  Cholesterol
# 3    “I stopped taking statins because of the horri...  Livalo  Cholesterol
# 4    “Livalo is the 5th statin I have tried.. was o...  Livalo  Cholesterol
# ..                                                 ...     ...          ...
# 96   “I have taken statins for the past 20 years, h...  Livalo  Cholesterol
# 97   “My doctor prescribed Livalo after I developed...  Livalo  Cholesterol
# 98   “I could not tolerate Lipitor. My Doctor switc...  Livalo  Cholesterol
# 99   “My doctor started me on 2mg Livalo about seve...  Livalo  Cholesterol
# 100  “The reason the doctor changed me to Livalo is...  Livalo  Cholesterol
#
#      Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                   15                   118                  3   oral
# 1                   15                   118                  3   oral
# 2                   15                   118                  3   oral
# 3                   15                   118                  3   oral
# 4                   15                   118                  3   oral
# ..                 ...                   ...                ...    ...
# 96                  15                   118                  3   oral
# 97                  15                   118                  3   oral
# 98                  15                   118                  3   oral
# 99                  15                   118                  3   oral
# 100                 15                   118                  3   oral
#
# [76 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/atorvastatin/lipitor-for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:17<00:00,  1.49s/it]

# %%
df7 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df7['Drug'] = 'Lipitor'
df7['Condition'] = 'Cholesterol'
df7['Major Interaction'] = 41
df7['Moderate Interaction'] = 235
df7['Minor Interaction'] = 33
df7['Dosage'] = 'injection'
df7.drop_duplicates(inplace=True)
df7
# Out:
#    Rating                Date                    Taken Helpful  \
# 0       1        June 6, 2020  Taken for 1 to 6 months      61
# 1       1        June 5, 2020  Taken for 1 to 6 months      46
# 2       2        May 23, 2020  Taken for 1 to 6 months      31
# 3       1      March 21, 2020  Taken for 1 to 6 months      25
# 4       1   February 22, 2020                      NaN      39
# ..    ...                 ...                      ...     ...
# 90      5   February 28, 2009                      NaN      91
# 91      3   February 17, 2009                      NaN     169
# 92      8  September 30, 2008                      NaN      28
# 93      9       July 28, 2008                      NaN      80
# 94     10       June 10, 2008                      NaN      69
#
#                                                Review     Drug    Condition  \
# 0   “So I went to the doctor for peripheral neurop...  Lipitor  Cholesterol
# 1   “After taking Lipitor for a few weeks I develo...  Lipitor  Cholesterol
# 2   “Horrible drug! Was taking 40mg once a day. Si...  Lipitor  Cholesterol
# 3   “Our mom took Lipitor and had a lot of swellin...  Lipitor  Cholesterol
# 4   “After first week 80mg Lipitor a day  extreme ...  Lipitor  Cholesterol
# ..                                                ...      ...          ...
# 90  “Lowers cholestorol but I have the oddest side...  Lipitor  Cholesterol
# 91  “Many side effects. Such as muscle pain, weakn...  Lipitor  Cholesterol
# 92                    “Works best for me with zetia.”  Lipitor  Cholesterol
# 93  “This medicine is wonderful. My cholesterol wa...  Lipitor  Cholesterol
# 94                                 “Works very well.”  Lipitor  Cholesterol
#
#     Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                  41                   235                 33  injection
# 1                  41                   235                 33  injection
# 2                  41                   235                 33  injection
# 3                  41                   235                 33  injection
# 4                  41                   235                 33  injection
# ..                ...                   ...                ...        ...
# 90                 41                   235                 33  injection
# 91                 41                   235                 33  injection
# 92                 41                   235                 33  injection
# 93                 41                   235                 33  injection
# 94                 41                   235                 33  injection
#
# [70 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/alirocumab/praluent-for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:18<00:00,  1.52s/it]

# %%
df8 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df8['Drug'] = 'Praluent'
df8['Condition'] = 'Cholesterol'
df8['Major Interaction'] = 0
df8['Moderate Interaction'] = 0
df8['Minor Interaction'] = 0
df8['Dosage'] = 'injection'
df8.drop_duplicates(inplace=True)
df8
# Out:
#    Rating               Date                        Taken Helpful  \
# 0       1   October 19, 2020  Taken for less than 1 month       0
# 1      10    October 5, 2020       Taken for 2 to 5 years       1
# 2       1    August 17, 2020      Taken for 1 to 6 months       9
# 3       1    August 15, 2020  Taken for less than 1 month      10
# 4       7     August 4, 2020  Taken for less than 1 month       8
# ..    ...                ...                          ...     ...
# 86      9      March 4, 2016      Taken for 1 to 6 months      50
# 87     10  February 20, 2016      Taken for 1 to 6 months      42
# 88     10  February 17, 2016      Taken for 1 to 6 months      27
# 89      2   January 18, 2016                          NaN      45
# 90     10   October 26, 2015                          NaN      41
#
#                                                Review      Drug    Condition  \
# 0   “I have Myasthenia Gravis and Praluent initial...  Praluent  Cholesterol
# 1   “After having a heart attack 2 years ago my ca...  Praluent  Cholesterol
# 2   “So I have been on Praluent for a month.  I wa...  Praluent  Cholesterol
# 3   “79 year old male 10 days ago had one injectio...  Praluent  Cholesterol
# 4   “I read a lot of negative comments on line abo...  Praluent  Cholesterol
# ..                                                ...       ...          ...
# 86  “I have experienced debilitating leg pain, bro...  Praluent  Cholesterol
# 87  “So far this drug is amazing!  I did my first ...  Praluent  Cholesterol
# 88  “After 4 injections my total cholesterol fell ...  Praluent  Cholesterol
# 89  “After three shots, my cholesterol came down o...  Praluent  Cholesterol
# 90  “I have more frequent bowel movements but not ...  Praluent  Cholesterol
#
#     Major Interaction  Moderate Interaction  Minor Interaction     Dosage
# 0                   0                     0                  0  injection
# 1                   0                     0                  0  injection
# 2                   0                     0                  0  injection
# 3                   0                     0                  0  injection
# 4                   0                     0                  0  injection
# ..                ...                   ...                ...        ...
# 86                  0                     0                  0  injection
# 87                  0                     0                  0  injection
# 88                  0                     0                  0  injection
# 89                  0                     0                  0  injection
# 90                  0                     0                  0  injection
#
# [66 rows x 11 columns]

# %%
url_template = "https://www.drugs.com/comments/niacin/for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:18<00:00,  1.52s/it]

# %%
df9 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df9['Drug'] = 'Niacin'
df9['Condition'] = 'Cholesterol'
df9['Major Interaction'] = 12
df9['Moderate Interaction'] = 72
df9['Minor Interaction'] = 12
df9['Dosage'] = 'oral'
df9.drop_duplicates(inplace=True)
df9.head()
# Out:
#   Rating               Date                       Taken Helpful  \
# 0      7   February 8, 2020     Taken for 1 to 6 months       2
# 1      9  November 16, 2019      Taken for 2 to 5 years       4
# 2      9       July 5, 2019  Taken for 10 years or more       7
# 3      7  February 27, 2019     Taken for 5 to 10 years       4
# 4      2  December 29, 2018  Taken for 10 years or more       5
#
#                                               Review    Drug    Condition  \
# 0  “I started on Niacin flush 500mg  for high cho...  Niacin  Cholesterol
# 1  Niaspan (niacin):\t\t\t“I have taken Niaspan 1...  Niacin  Cholesterol
# 2  Niacin SR (niacin):\t\t\t“I have been taking N...  Niacin  Cholesterol
# 3  Niaspan (niacin):\t\t\t“I have been taking Nia...  Niacin  Cholesterol
# 4  Niaspan (niacin):\t\t\t“I took maximum dose of...  Niacin  Cholesterol
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                 12                    72                 12   oral
# 1                 12                    72                 12   oral
# 2                 12                    72                 12   oral
# 3                 12                    72                 12   oral
# 4                 12                    72                 12   oral

# %%
url_template = "https://www.drugs.com/comments/ezetimibe/zetia-for-hyperlipidemia.html?page={}"
max_results_per_page = 12
rating = []
review = []
date = []
taken = []
likes = []

for start in tqdm(range(max_results_per_page)):
        r1 = requests.get(url_template.format(start))
        soup = BeautifulSoup(r1.text, 'html.parser')
        start = time()
        while time()-start<1: continue
     
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                rating.append(x.find('div', attrs={'class': 'ddc-rating-summary'}).find('b').text)
            except:
                rating.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                review.append(x.find('p', attrs={'class': 'ddc-comment-content'}).text.strip())
            except:
                review.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                date.append(x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class', 'comment-date'}).text)
            except:
                date.append(np.nan)
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                likes.append(x.find('div', attrs={'class': 'ddc-comment-actions'}).next_sibling.next_sibling.find('a').text)
            except:
                likes.append(np.nan)
            
    
        for x in soup.find_all('div', attrs={'class': 'ddc-comment'}):
            try:
                taken.append((x.find('div', attrs={'class': 'ddc-comment-section'}).find('span', attrs={'class': 'ddc-text-color-secondary'}).next_sibling.next_sibling).text)
            except:
                taken.append(np.nan)
# Out:
# 100%|██████████| 12/12 [00:17<00:00,  1.45s/it]

# %%
df10 = pd.DataFrame({'Rating': rating,
            'Date': date,
            'Taken': taken,
            'Helpful': likes,
            'Review': review})

df10['Drug'] = 'Zetia'
df10['Condition'] = 'Cholesterol'
df10['Major Interaction'] = 0
df10['Moderate Interaction'] = 30
df10['Minor Interaction'] = 4
df10['Dosage'] = 'oral'
df10.drop_duplicates(inplace=True)
df10.head()
# Out:
#   Rating               Date                        Taken Helpful  \
# 0      5   October 30, 2020      Taken for 1 to 6 months       3
# 1     10  November 29, 2019  Taken for less than 1 month      63
# 2      1  November 13, 2019  Taken for less than 1 month      73
# 3      1  November 10, 2019  Taken for less than 1 month      51
# 4    NaN      July 29, 2019                          NaN      61
#
#                                               Review   Drug    Condition  \
# 0  “Started on Zetia on top of Crestor. Still tak...  Zetia  Cholesterol
# 1  “I was put on Lipitor for lipid reduction. Did...  Zetia  Cholesterol
# 2  “I cannot take statins as they tank my depress...  Zetia  Cholesterol
# 3  “My experience was horrible two weeks in burpi...  Zetia  Cholesterol
# 4  “I can't take statins they make me hurt so bad...  Zetia  Cholesterol
#
#    Major Interaction  Moderate Interaction  Minor Interaction Dosage
# 0                  0                    30                  4   oral
# 1                  0                    30                  4   oral
# 2                  0                    30                  4   oral
# 3                  0                    30                  4   oral
# 4                  0                    30                  4   oral

# %%
frames = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
df_cholesterol = pd.concat(frames)

# %%
df_cholesterol.reset_index(inplace=True, drop=True)

# %%
#save to CSV as master 
df_cholesterol.to_csv("df_cholesterol.csv")
